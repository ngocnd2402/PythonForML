# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
# !pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (23.5.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)

# %%
import numpy as np
import pandas as pd
from joblib import dump, load
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
from sklearn.metrics import fbeta_score
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import plot_tree
from sklearn.preprocessing import LabelEncoder
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import precision_recall_curve, auc
import xgboost as xgb
from joblib import dump, load
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
warnings.filterwarnings("ignore", category=UserWarning, module="skopt")
# %matplotlib inline

# %% [markdown]
# ## Financial Dataset for Fraud Detection in a Company
#
# This dataset contains information about financial transactions in a company and is specifically designed for fraud detection. It consists of the following 9 columns:
#
# - **step**: The number of minutes elapsed between each transaction.
# - **type**: The type of transaction, which can be one of the following categories: CASH_IN, CASH_OUT, DEBIT, PAYMENT, TRANSFER.
# - **amount**: The amount of money involved in the transaction.
# - **nameOrig**: The name of the person or entity originating the transaction.
# - **oldbalanceOrg**: The original balance of the account before the transaction took place.
# - **newbalanceOrig**: The balance of the account after the transaction was performed.
# - **nameDest**: The name of the person or entity receiving the transaction.
# - **oldbalanceDest**: The original balance of the recipient's account before the transaction took place.
# - **newbalanceDest**: The balance of the recipient's account after the transaction was performed.
#
# The data in this dataset is used to detect fraud in financial transactions. It can be used to train machine learning models to identify fraudulent transactions and to prevent fraudulent activities in a company.

# %% [markdown]
# # LOADING THE DATASET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data = pd.read_csv('/kaggle/input/pythonforml/data.csv')
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Final Project/data.csv')

# %%
# data_temp = pd.read_csv('/kaggle/input/pythonforml/data.csv')
data_temp = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Final Project/data.csv')

# %%
cd /content/drive/MyDrive/Colab Notebooks/Final Project
# Out:
# /content/drive/MyDrive/Colab Notebooks/Final Project

# %% [markdown]
# # DATA EXPLORATION
#
# ### 1. check target column for data imbalance-- to balance data set before train/test models
# ### 2. explore and find out which columns to use for modeling

# %%
# check total number of rows and columns
print('total rows and columns:', data.shape)
# Out:
# total rows and columns: (6362620, 11)

# %%
# take a look at the data
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# check data for duplicates
data = data.drop_duplicates()

# check the number of total rows again, in this case, there are no duplicates
print('total rows and columns after drop duplicates', data.shape)
# Out:
# total rows and columns after drop duplicates (6362620, 11)

# %%
# check null values  -- data has no missing values
data.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
data.info()      # show numerical and character columns
# find out which columns are relevant to use in the models, by looking at the numeric and categorical values separately
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 582.5+ MB

# %%
# create column list, so all modifications made to the orignal dataframe
num_col_list = ['step','amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest','isFraud','isFlaggedFraud']
char_col_list = ['type','nameOrig','nameDest']

# %%
# Lặp qua từng cột trong num_col_list và vẽ biểu đồ KDE
for column in num_col_list:
    plt.figure(figsize=(8, 6))
    sns.kdeplot(data[column], color='red', fill=True)
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.title(f'Distribution of {column}')
    plt.tight_layout()
    plt.show()

# %%
color = '#1f77b4'

# Vẽ biểu đồ histogram cho các biến số
for column in num_col_list:
    plt.figure(figsize=(8, 6))

    # Vẽ biểu đồ histogram
    plt.hist(data[column], bins=30, color=color, edgecolor='black')

    # Thiết lập tiêu đề và nhãn trục
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')

    # Hiển thị biểu đồ
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo DataFrame với các cột value và target
columns = ['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest']
target = 'isFraud'
df = data_temp[columns + [target]]

df_encoded = df.copy()
for col in ['type', 'nameOrig', 'nameDest']:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

# Tính ma trận tương quan
correlation_matrix = df_encoded.corr()

# Vẽ heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# too many unique values in nameOrig, nameDest, we do some feature engineering-- assign them into C or M, customer or merchant
data['nameOrig'] = data['nameOrig'].apply(lambda x: x[0:1])
data['nameOrig'].value_counts()
data['nameDest'] = data['nameDest'].apply(lambda x: x[0:1])
data['nameDest'].value_counts()
data.head(10)
# Out:
#    step      type    amount nameOrig  oldbalanceOrg  newbalanceOrig nameDest  \
# 0     1   PAYMENT   9839.64        C      170136.00       160296.36        M
# 1     1   PAYMENT   1864.28        C       21249.00        19384.72        M
# 2     1  TRANSFER    181.00        C         181.00            0.00        C
# 3     1  CASH_OUT    181.00        C         181.00            0.00        C
# 4     1   PAYMENT  11668.14        C       41554.00        29885.86        M
# 5     1   PAYMENT   7817.71        C       53860.00        46042.29        M
# 6     1   PAYMENT   7107.77        C      183195.00       176087.23        M
# 7     1   PAYMENT   7861.64        C      176087.23       168225.59        M
# 8     1   PAYMENT   4024.36        C        2671.00            0.00        M
# 9     1     DEBIT   5337.77        C       41720.00        36382.23        C
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0             0.0            0.00        0               0
# 1             0.0            0.00        0               0
# 2             0.0            0.00        1               0
# 3         21182.0            0.00        1               0
# 4             0.0            0.00        0               0
# 5             0.0            0.00        0               0
# 6             0.0            0.00        0               0
# 7             0.0            0.00        0               0
# 8             0.0            0.00        0               0
# 9         41898.0        40348.79        0               0

# %%
# Tạo pivot table
fraud_type_counts = pd.pivot_table(data, index='isFraud', columns='type', values='nameDest', aggfunc='count')

# Lưu kết quả vào biến
fraud_type_counts_chart_1 = fraud_type_counts.iloc[1]  # Chỉ lấy hàng tương ứng với fraud
fraud_type_counts_chart_1 = fraud_type_counts_chart_1.rename({0: 'CASH_IN', 1: 'CASH_OUT', 2: 'DEBIT', 3: 'PAYMENT', 4: 'TRANSFER'})

# Vẽ biểu đồ so sánh với fraud
plt.figure(figsize=(10, 6))

# Biểu đồ loại giao dịch 1 (type)
plt.subplot(1, 2, 1)
fraud_type_counts_chart_1.plot(kind='bar')
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Fraud Counts by Type')

# Tạo pivot table
fraud_type_counts = pd.pivot_table(data, index='isFraud', columns='type', values='nameDest', aggfunc='count')

# Lưu kết quả vào biến
fraud_type_counts_chart_2 = fraud_type_counts.iloc[:, 0:5]  # Lấy tất cả cột từ 0 đến 4 (bao gồm cả 'CASH_IN')
fraud_type_counts_chart_2.columns = ['CASH_IN', 'CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER']

# Thay đổi thứ tự cột trong dataframe
fraud_type_counts_chart_2 = fraud_type_counts_chart_2[['CASH_IN', 'CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER']]

# Vẽ biểu đồ cột đôi
plt.subplot(1, 2, 2)

# Chỉ số các loại giao dịch
x = np.arange(len(fraud_type_counts_chart_2.columns))

# Chiều rộng của cột
width = 0.35

# Biểu đồ loại giao dịch 2 (type)
plt.bar(x - width/2, fraud_type_counts_chart_2.iloc[0], width, color='gray', label='False')
plt.bar(x + width/2, fraud_type_counts_chart_2.iloc[1], width, color='red', label='True', alpha=0.8)

# Thiết lập các thông số biểu đồ
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Fraud Counts by Type')
plt.xticks(x, fraud_type_counts_chart_2.columns)
plt.legend()

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
# looks like only case_out and transfer is associate with fraud; and only customer is associate with fraud !

# Danh sách tên loại giao dịch
type_names = ['CASH_IN', 'CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER']

# Tạo biểu đồ tròn
plt.figure(figsize=(10, 8))
plt.pie(data.type.value_counts().values, labels=type_names, autopct='%.0f%%')

# Thiết lập tiêu đề
plt.title("Transaction Type")

# Hiển thị biểu đồ
plt.show()

# %%
data['type'] = data['type']
data_counts = data['type'].value_counts()
print(data_counts)
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
# Số lượng mẫu muốn giữ lại cho "CASH_IN", "PAYMENT" và "DEBIT"
samples_per_type = 10000

# Lọc và giữ nguyên tất cả các mẫu cho "TRANSFER" và "CASH_OUT"
new_data = data[data['type'].isin(['TRANSFER', 'CASH_OUT'])]

# Lọc và giữ lại số lượng mẫu mong muốn cho "CASH_IN", "PAYMENT" và "DEBIT"
for t in ['CASH_IN', 'PAYMENT', 'DEBIT']:
    subset = data[data['type'] == t].sample(n=samples_per_type, random_state=42)
    new_data = pd.concat([new_data, subset])

# Reset chỉ số của dataframe kết quả
new_data = new_data.reset_index(drop=True)
new_data['type'].value_counts()
# Out:
# CASH_OUT    2237500
# TRANSFER     532909
# CASH_IN       10000
# PAYMENT       10000
# DEBIT         10000
# Name: type, dtype: int64

# %%
# check target value for imbalance--- in this case the target value is highly imbalanced: fraud: 8213, non-fraud 6354407, that's 1:773 ratio
print(new_data['isFraud'].value_counts())
fraud_counts = new_data['isFraud'].value_counts()
plt.bar(fraud_counts.index, fraud_counts.values)
plt.xlabel('Result')
plt.ylabel('n_samples')
plt.xticks(fraud_counts.index, ['Not Fraud', 'Fraud'])
plt.title('Check Fraud')
plt.show()
# Out:
# 0    2792196
# 1       8213
# Name: isFraud, dtype: int64

# %% [markdown]
# # DATA PREPARATION
#
# ### 1. Create numeric values for character columns

# %%
# create numeric values for character columns
encoder = {}
for i in new_data.select_dtypes('object').columns:
    encoder[i] = LabelEncoder()
    new_data[i] = encoder[i].fit_transform(new_data[i])
new_data.head(10)
# Out:
#    step  type     amount  nameOrig  oldbalanceOrg  newbalanceOrig  nameDest  \
# 0     1     4     181.00         0         181.00             0.0         0
# 1     1     1     181.00         0         181.00             0.0         0
# 2     1     1  229133.94         0       15325.00             0.0         0
# 3     1     4  215310.30         0         705.00             0.0         0
# 4     1     4  311685.89         0       10835.00             0.0         0
# 5     1     1  110414.71         0       26845.41             0.0         0
# 6     1     1   56953.90         0        1942.02             0.0         0
# 7     1     1    5346.89         0           0.00             0.0         0
# 8     1     1   23261.30         0       20411.53             0.0         0
# 9     1     4   62610.80         0       79114.00         16503.2         0
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0             0.0            0.00        1               0
# 1         21182.0            0.00        1               0
# 2          5083.0        51513.44        0               0
# 3         22425.0            0.00        0               0
# 4          6267.0      2719172.89        0               0
# 5        288800.0         2415.16        0               0
# 6         70253.0        64106.18        0               0
# 7        652637.0      6453430.91        0               0
# 8         25742.0            0.00        0               0
# 9           517.0         8383.29        0               0

# %% [markdown]
# # TRAINING AND TESTING DATA
#
# ### Split data into traing set and testing set
# ### Scale the training data

# %%
#Use StandardScaler to normalize the data
normer = StandardScaler()
X_full = new_data.drop(columns=['isFraud'],axis=1)
X_full = X_full.to_numpy()
y_full = new_data['isFraud']
y_full = y_full.astype('int')
y_full = y_full.to_numpy()
# Initialize StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

# Perform StratifiedShuffleSplit cross-validation
for i, (train_index, test_index) in enumerate(sss.split(X_full, y_full), 1):
    X_train, X_test = X_full[train_index], X_full[test_index]
    y_train, y_test = y_full[train_index], y_full[test_index]

X_train = normer.fit_transform(X_train)
X_test = normer.transform(X_test)

# %% [markdown]
# # Building model

# %% [markdown]
# ## XGBoost

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical

# Define the number of splits and the test size for StratifiedShuffleSplit
num_splits = 3
test_size = 0.3

# Initialize StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=num_splits, test_size=test_size, random_state=42)

# Define the parameter search space
param_space = {
    'max_depth': Integer(1, 10),
}

# Initialize XGBClassifier with default parameters
xgb_model = xgb.XGBClassifier(tree_method='gpu_hist', n_estimators=200, learning_rate = 0.1)

# Initialize BayesSearchCV
bayes_search_xgb = BayesSearchCV(
    estimator= xgb_model,
    search_spaces=param_space,
    n_iter=30,  # Number of iterations for Bayesian Optimization
    cv=sss,
)

# Fit BayesSearchCV on the normalized data
bayes_search_xgb.fit(X_train, y_train)

# Get the best parameters and best score
best_params = bayes_search_xgb.best_params_
best_score = bayes_search_xgb.best_score_

# Print the best parameters and best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Save the model to disk
filename = 'bayes_search_xgboost.sav'
dump(bayes_search_xgb, filename)
# Out:
# Best Parameters: OrderedDict([('max_depth', 9)])
# Best Score: 0.9994388575820543
# ['bayes_search_xgboost.sav']

# %%
# specify the path
path = '/content/drive/MyDrive/Colab Notebooks/Final Project/bayes_search_xgboost.sav'
# load the model
loaded_model_xgb = load(path)

# Make predictions on the test data
y_pred = loaded_model_xgb.predict(X_test)
y_scores = loaded_model_xgb.predict_proba(X_test)[:, 1]

# Accuracy
accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
print(f"Accuracy for class 0: {accuracy_class_0*100}%")
print(f"Accuracy for class 1: {accuracy_class_1*100}%")

# F2 score
f2 = fbeta_score(y_test, y_pred, beta=2)
print(f"F2 Score: {f2}")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title("Confusion Matrix")
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_scores)  # Calculate precision, recall
pr_auc = auc(recall, precision)  # Calculate Precision-Recall AUC
plt.figure()
plt.plot(recall, precision, label=f"Precision-Recall Curve (AUC = {pr_auc:.2f})")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()

# Classification report
report = classification_report(y_test, y_pred)
print(f"Classification Report:\n{report}")
# Out:
# Accuracy for class 0: 99.98842010889872%
# Accuracy for class 1: 85.47077922077922%
# F2 Score: 0.8732067335599967
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    837659
#            1       0.96      0.85      0.90      2464
#
#     accuracy                           1.00    840123
#    macro avg       0.98      0.93      0.95    840123
# weighted avg       1.00      1.00      1.00    840123

# %% [markdown]
# ## CatBoost

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical

# Define the number of splits and the test size for StratifiedShuffleSplit
num_splits = 3
test_size = 0.3

# Initialize StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=num_splits, test_size=test_size, random_state=42)

# Define the parameter search space
param_space = {
    'max_depth': Integer(1, 10),
}

# Initialize CatBoostClassifier with default parameters
catboost_model = CatBoostClassifier(iterations=200, learning_rate=0.1, task_type='GPU')

# Initialize BayesSearchCV
bayes_search_catboost = BayesSearchCV(
    estimator=catboost_model,
    search_spaces=param_space,
    n_iter=30,  # Number of iterations for Bayesian Optimization
    cv=sss,
)

# Fit BayesSearchCV on the normalized data
bayes_search_catboost.fit(X_train, y_train)

# Get the best parameters and best score
best_params = bayes_search_catboost.best_params_
best_score = bayes_search_catboost.best_score_

# Print the best parameters and best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Save the model to disk
filename = 'bayes_search_cat.sav'
dump(bayes_search_catboost, filename)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 2:	learn: 0.1410308	total: 63.4ms	remaining: 4.17s
# 3:	learn: 0.0860546	total: 84.2ms	remaining: 4.13s
# 4:	learn: 0.0556912	total: 108ms	remaining: 4.22s
# 5:	learn: 0.0388952	total: 129ms	remaining: 4.18s
# 6:	learn: 0.0279924	total: 150ms	remaining: 4.14s
# 7:	learn: 0.0215632	total: 171ms	remaining: 4.11s
# 8:	learn: 0.0170398	total: 193ms	remaining: 4.09s
# 9:	learn: 0.0142811	total: 214ms	remaining: 4.07s
# 10:	learn: 0.0124232	total: 252ms	remaining: 4.33s
# 11:	learn: 0.0108468	total: 271ms	remaining: 4.25s
# 12:	learn: 0.0093652	total: 288ms	remaining: 4.14s
# 13:	learn: 0.0083338	total: 304ms	remaining: 4.04s
# 14:	learn: 0.0076652	total: 320ms	remaining: 3.95s
# 15:	learn: 0.0070894	total: 340ms	remaining: 3.9s
# 16:	learn: 0.0066776	total: 356ms	remaining: 3.83s
# 17:	learn: 0.0063952	total: 372ms	remaining: 3.76s
# 18:	learn: 0.0060715	total: 388ms	remaining: 3.69s
# 19:	learn: 0.0058666	total: 404ms	remaining: 3.64s
# 20:	learn: 0.0057135	total: 421ms	remaining: 3.58s
# 21:	learn: 0.0053142	total: 436ms	remaining: 3.53s
# 22:	learn: 0.0052526	total: 463ms	remaining: 3.56s
# 23:	learn: 0.0051935	total: 478ms	remaining: 3.5s
# 24:	learn: 0.0049963	total: 492ms	remaining: 3.45s
# 25:	learn: 0.0048226	total: 507ms	remaining: 3.39s
# 26:	learn: 0.0047809	total: 522ms	remaining: 3.34s
# 27:	learn: 0.0046882	total: 536ms	remaining: 3.29s
# 28:	learn: 0.0045823	total: 551ms	remaining: 3.25s
# 29:	learn: 0.0044938	total: 566ms	remaining: 3.21s
# 30:	learn: 0.0044309	total: 580ms	remaining: 3.16s
# 31:	learn: 0.0044060	total: 595ms	remaining: 3.12s
# 32:	learn: 0.0043285	total: 609ms	remaining: 3.08s
# 33:	learn: 0.0042942	total: 623ms	remaining: 3.04s
# 34:	learn: 0.0042728	total: 638ms	remaining: 3.01s
# 35:	learn: 0.0042556	total: 653ms	remaining: 2.97s
# 36:	learn: 0.0042117	total: 677ms	remaining: 2.98s
# 37:	learn: 0.0041698	total: 693ms	remaining: 2.95s
# 38:	learn: 0.0041386	total: 707ms	remaining: 2.92s
# 39:	learn: 0.0041126	total: 722ms	remaining: 2.89s
# 40:	learn: 0.0040831	total: 736ms	remaining: 2.85s
# 41:	learn: 0.0040257	total: 750ms	remaining: 2.82s
# 42:	learn: 0.0039922	total: 764ms	remaining: 2.79s
# 43:	learn: 0.0039695	total: 779ms	remaining: 2.76s
# 44:	learn: 0.0039547	total: 793ms	remaining: 2.73s
# 45:	learn: 0.0039432	total: 808ms	remaining: 2.71s
# 46:	learn: 0.0039081	total: 823ms	remaining: 2.68s
# 47:	learn: 0.0039013	total: 838ms	remaining: 2.65s
# 48:	learn: 0.0038542	total: 852ms	remaining: 2.63s
# 49:	learn: 0.0038321	total: 867ms	remaining: 2.6s
# 50:	learn: 0.0038265	total: 892ms	remaining: 2.61s
# 51:	learn: 0.0038115	total: 907ms	remaining: 2.58s
# 52:	learn: 0.0038058	total: 921ms	remaining: 2.56s
# 53:	learn: 0.0037516	total: 940ms	remaining: 2.54s
# 54:	learn: 0.0037368	total: 963ms	remaining: 2.54s
# 55:	learn: 0.0037160	total: 977ms	remaining: 2.51s
# 56:	learn: 0.0037126	total: 995ms	remaining: 2.5s
# 57:	learn: 0.0036878	total: 1.01s	remaining: 2.47s
# 58:	learn: 0.0036721	total: 1.02s	remaining: 2.45s
# 59:	learn: 0.0036647	total: 1.04s	remaining: 2.42s
# 60:	learn: 0.0036578	total: 1.05s	remaining: 2.4s
# 61:	learn: 0.0036421	total: 1.07s	remaining: 2.38s
# 62:	learn: 0.0036061	total: 1.08s	remaining: 2.35s
# 63:	learn: 0.0036022	total: 1.11s	remaining: 2.35s
# 64:	learn: 0.0035836	total: 1.12s	remaining: 2.33s
# 65:	learn: 0.0035352	total: 1.14s	remaining: 2.31s
# 66:	learn: 0.0035096	total: 1.15s	remaining: 2.29s
# 67:	learn: 0.0034952	total: 1.17s	remaining: 2.27s
# 68:	learn: 0.0034912	total: 1.18s	remaining: 2.24s
# 69:	learn: 0.0034881	total: 1.2s	remaining: 2.22s
# 70:	learn: 0.0034408	total: 1.21s	remaining: 2.2s
# 71:	learn: 0.0034155	total: 1.22s	remaining: 2.18s
# 72:	learn: 0.0034020	total: 1.24s	remaining: 2.16s
# 73:	learn: 0.0033966	total: 1.25s	remaining: 2.13s
# 74:	learn: 0.0033883	total: 1.27s	remaining: 2.12s
# 75:	learn: 0.0033771	total: 1.29s	remaining: 2.1s
# 76:	learn: 0.0033540	total: 1.32s	remaining: 2.1s
# 77:	learn: 0.0033263	total: 1.33s	remaining: 2.08s
# 78:	learn: 0.0033034	total: 1.34s	remaining: 2.06s
# 79:	learn: 0.0032899	total: 1.36s	remaining: 2.04s
# 80:	learn: 0.0032790	total: 1.38s	remaining: 2.02s
# 81:	learn: 0.0032679	total: 1.39s	remaining: 2s
# 82:	learn: 0.0032643	total: 1.4s	remaining: 1.98s
# 83:	learn: 0.0032559	total: 1.42s	remaining: 1.96s
# 84:	learn: 0.0032371	total: 1.43s	remaining: 1.94s
# 85:	learn: 0.0032230	total: 1.45s	remaining: 1.92s
# 86:	learn: 0.0032079	total: 1.46s	remaining: 1.9s
# 87:	learn: 0.0032049	total: 1.48s	remaining: 1.88s
# 88:	learn: 0.0031935	total: 1.49s	remaining: 1.86s
# 89:	learn: 0.0031768	total: 1.51s	remaining: 1.84s
# 90:	learn: 0.0031656	total: 1.54s	remaining: 1.85s
# 91:	learn: 0.0031631	total: 1.56s	remaining: 1.83s
# 92:	learn: 0.0031521	total: 1.57s	remaining: 1.81s
# 93:	learn: 0.0031428	total: 1.59s	remaining: 1.79s
# 94:	learn: 0.0031322	total: 1.6s	remaining: 1.77s
# 95:	learn: 0.0031239	total: 1.62s	remaining: 1.75s
# 96:	learn: 0.0031194	total: 1.63s	remaining: 1.73s
# 97:	learn: 0.0030922	total: 1.65s	remaining: 1.71s
# 98:	learn: 0.0030884	total: 1.66s	remaining: 1.69s
# 99:	learn: 0.0030656	total: 1.67s	remaining: 1.67s
# 100:	learn: 0.0030633	total: 1.69s	remaining: 1.66s
# 101:	learn: 0.0030610	total: 1.7s	remaining: 1.64s
# 102:	learn: 0.0030534	total: 1.72s	remaining: 1.62s
# 103:	learn: 0.0030500	total: 1.73s	remaining: 1.6s
# 104:	learn: 0.0030474	total: 1.76s	remaining: 1.59s
# 105:	learn: 0.0030397	total: 1.77s	remaining: 1.57s
# 106:	learn: 0.0030207	total: 1.8s	remaining: 1.56s
# 107:	learn: 0.0030096	total: 1.81s	remaining: 1.54s
# 108:	learn: 0.0029988	total: 1.83s	remaining: 1.52s
# 109:	learn: 0.0029890	total: 1.84s	remaining: 1.51s
# 110:	learn: 0.0029702	total: 1.85s	remaining: 1.49s
# 111:	learn: 0.0029619	total: 1.87s	remaining: 1.47s
# 112:	learn: 0.0029593	total: 1.88s	remaining: 1.45s
# 113:	learn: 0.0029490	total: 1.9s	remaining: 1.43s
# 114:	learn: 0.0029412	total: 1.91s	remaining: 1.41s
# 115:	learn: 0.0029387	total: 1.94s	remaining: 1.4s
# 116:	learn: 0.0029352	total: 1.96s	remaining: 1.39s
# 117:	learn: 0.0029244	total: 1.98s	remaining: 1.37s
# 118:	learn: 0.0029213	total: 1.99s	remaining: 1.36s
# 119:	learn: 0.0029192	total: 2.01s	remaining: 1.34s
# 120:	learn: 0.0029169	total: 2.02s	remaining: 1.32s
# 121:	learn: 0.0029147	total: 2.04s	remaining: 1.3s
# 122:	learn: 0.0029130	total: 2.05s	remaining: 1.28s
# 123:	learn: 0.0029029	total: 2.06s	remaining: 1.27s
# 124:	learn: 0.0029014	total: 2.08s	remaining: 1.25s
# 125:	learn: 0.0028997	total: 2.09s	remaining: 1.23s
# 126:	learn: 0.0028957	total: 2.11s	remaining: 1.21s
# 127:	learn: 0.0028943	total: 2.13s	remaining: 1.2s
# 128:	learn: 0.0028814	total: 2.14s	remaining: 1.18s
# 129:	learn: 0.0028809	total: 2.15s	remaining: 1.16s
# 130:	learn: 0.0028702	total: 2.18s	remaining: 1.15s
# 131:	learn: 0.0028669	total: 2.19s	remaining: 1.13s
# 132:	learn: 0.0028508	total: 2.21s	remaining: 1.11s
# 133:	learn: 0.0028500	total: 2.22s	remaining: 1.09s
# 134:	learn: 0.0028488	total: 2.24s	remaining: 1.08s
# 135:	learn: 0.0028456	total: 2.25s	remaining: 1.06s
# 136:	learn: 0.0028433	total: 2.27s	remaining: 1.04s
# 137:	learn: 0.0028396	total: 2.28s	remaining: 1.02s
# 138:	learn: 0.0028260	total: 2.29s	remaining: 1.01s
# 139:	learn: 0.0028111	total: 2.31s	remaining: 990ms
# 140:	learn: 0.0027998	total: 2.32s	remaining: 973ms
# 141:	learn: 0.0027944	total: 2.34s	remaining: 955ms
# 142:	learn: 0.0027906	total: 2.36s	remaining: 941ms
# 143:	learn: 0.0027812	total: 2.38s	remaining: 927ms
# 144:	learn: 0.0027780	total: 2.4s	remaining: 910ms
# 145:	learn: 0.0027686	total: 2.41s	remaining: 892ms
# 146:	learn: 0.0027655	total: 2.43s	remaining: 875ms
# 147:	learn: 0.0027620	total: 2.44s	remaining: 858ms
# 148:	learn: 0.0027577	total: 2.46s	remaining: 840ms
# 149:	learn: 0.0027568	total: 2.47s	remaining: 823ms
# 150:	learn: 0.0027546	total: 2.48s	remaining: 806ms
# 151:	learn: 0.0027538	total: 2.5s	remaining: 789ms
# 152:	learn: 0.0027504	total: 2.51s	remaining: 772ms
# 153:	learn: 0.0027425	total: 2.53s	remaining: 755ms
# 154:	learn: 0.0027410	total: 2.54s	remaining: 738ms
# 155:	learn: 0.0027377	total: 2.56s	remaining: 721ms
# 156:	learn: 0.0027347	total: 2.57s	remaining: 704ms
# 157:	learn: 0.0027283	total: 2.59s	remaining: 689ms
# 158:	learn: 0.0027256	total: 2.61s	remaining: 673ms
# 159:	learn: 0.0027254	total: 2.62s	remaining: 655ms
# 160:	learn: 0.0027154	total: 2.63s	remaining: 638ms
# 161:	learn: 0.0027079	total: 2.65s	remaining: 622ms
# 162:	learn: 0.0027056	total: 2.66s	remaining: 605ms
# 163:	learn: 0.0027019	total: 2.68s	remaining: 588ms
# 164:	learn: 0.0027014	total: 2.69s	remaining: 571ms
# 165:	learn: 0.0026987	total: 2.71s	remaining: 555ms
# 166:	learn: 0.0026971	total: 2.72s	remaining: 538ms
# 167:	learn: 0.0026848	total: 2.74s	remaining: 521ms
# 168:	learn: 0.0026839	total: 2.75s	remaining: 505ms
# 169:	learn: 0.0026773	total: 2.77s	remaining: 488ms
# 170:	learn: 0.0026715	total: 2.78s	remaining: 472ms
# 171:	learn: 0.0026650	total: 2.81s	remaining: 458ms
# 172:	learn: 0.0026595	total: 2.83s	remaining: 442ms
# 173:	learn: 0.0026502	total: 2.84s	remaining: 425ms
# 174:	learn: 0.0026469	total: 2.86s	remaining: 408ms
# 175:	learn: 0.0026450	total: 2.87s	remaining: 392ms
# 176:	learn: 0.0026407	total: 2.89s	remaining: 375ms
# 177:	learn: 0.0026383	total: 2.91s	remaining: 360ms
# 178:	learn: 0.0026366	total: 2.93s	remaining: 344ms
# 179:	learn: 0.0026329	total: 2.94s	remaining: 327ms
# 180:	learn: 0.0026286	total: 2.96s	remaining: 310ms
# 181:	learn: 0.0026221	total: 2.97s	remaining: 294ms
# 182:	learn: 0.0026198	total: 2.99s	remaining: 278ms
# 183:	learn: 0.0026146	total: 3.01s	remaining: 262ms
# 184:	learn: 0.0026103	total: 3.02s	remaining: 245ms
# 185:	learn: 0.0026086	total: 3.04s	remaining: 229ms
# 186:	learn: 0.0026075	total: 3.05s	remaining: 212ms
# 187:	learn: 0.0025980	total: 3.07s	remaining: 196ms
# 188:	learn: 0.0025957	total: 3.08s	remaining: 180ms
# 189:	learn: 0.0025874	total: 3.1s	remaining: 163ms
# 190:	learn: 0.0025782	total: 3.11s	remaining: 147ms
# 191:	learn: 0.0025716	total: 3.13s	remaining: 130ms
# 192:	learn: 0.0025665	total: 3.14s	remaining: 114ms
# 193:	learn: 0.0025641	total: 3.15s	remaining: 97.6ms
# 194:	learn: 0.0025621	total: 3.17s	remaining: 81.3ms
# 195:	learn: 0.0025602	total: 3.18s	remaining: 65ms
# 196:	learn: 0.0025590	total: 3.2s	remaining: 48.7ms
# 197:	learn: 0.0025587	total: 3.22s	remaining: 32.6ms
# 198:	learn: 0.0025545	total: 3.24s	remaining: 16.3ms
# 199:	learn: 0.0025529	total: 3.25s	remaining: 0us
# 0:	learn: 0.3982235	total: 58.8ms	remaining: 11.7s
# 1:	learn: 0.2318619	total: 123ms	remaining: 12.2s
# 2:	learn: 0.1407743	total: 191ms	remaining: 12.5s
# 3:	learn: 0.0857495	total: 258ms	remaining: 12.6s
# 4:	learn: 0.0552466	total: 328ms	remaining: 12.8s
# 5:	learn: 0.0380419	total: 388ms	remaining: 12.5s
# 6:	learn: 0.0277761	total: 454ms	remaining: 12.5s
# 7:	learn: 0.0214233	total: 514ms	remaining: 12.3s
# 8:	learn: 0.0171748	total: 574ms	remaining: 12.2s
# 9:	learn: 0.0143765	total: 637ms	remaining: 12.1s
# 10:	learn: 0.0124922	total: 699ms	remaining: 12s
# 11:	learn: 0.0105467	total: 760ms	remaining: 11.9s
# 12:	learn: 0.0091723	total: 824ms	remaining: 11.8s
# 13:	learn: 0.0083746	total: 887ms	remaining: 11.8s
# 14:	learn: 0.0076086	total: 935ms	remaining: 11.5s
# 15:	learn: 0.0070518	total: 971ms	remaining: 11.2s
# 16:	learn: 0.0066131	total: 992ms	remaining: 10.7s
# 17:	learn: 0.0061926	total: 1.01s	remaining: 10.2s
# 18:	learn: 0.0059426	total: 1.03s	remaining: 9.84s
# 19:	learn: 0.0057572	total: 1.05s	remaining: 9.49s
# 20:	learn: 0.0053977	total: 1.07s	remaining: 9.16s
# 21:	learn: 0.0051293	total: 1.1s	remaining: 8.87s
# 22:	learn: 0.0050556	total: 1.12s	remaining: 8.59s
# 23:	learn: 0.0049644	total: 1.13s	remaining: 8.31s
# 24:	learn: 0.0047548	total: 1.15s	remaining: 8.05s
# 25:	learn: 0.0046070	total: 1.18s	remaining: 7.88s
# 26:	learn: 0.0045714	total: 1.19s	remaining: 7.65s
# 27:	learn: 0.0045432	total: 1.21s	remaining: 7.45s
# 28:	learn: 0.0045152	total: 1.23s	remaining: 7.27s
# 29:	learn: 0.0043932	total: 1.25s	remaining: 7.08s
# 30:	learn: 0.0043248	total: 1.27s	remaining: 6.9s
# 31:	learn: 0.0042613	total: 1.29s	remaining: 6.78s
# 32:	learn: 0.0041871	total: 1.31s	remaining: 6.63s
# 33:	learn: 0.0041417	total: 1.32s	remaining: 6.46s
# 34:	learn: 0.0040832	total: 1.34s	remaining: 6.31s
# 35:	learn: 0.0040502	total: 1.35s	remaining: 6.16s
# 36:	learn: 0.0040245	total: 1.39s	remaining: 6.12s
# 37:	learn: 0.0039987	total: 1.41s	remaining: 6s
# 38:	learn: 0.0039835	total: 1.42s	remaining: 5.87s
# 39:	learn: 0.0039672	total: 1.44s	remaining: 5.75s
# 40:	learn: 0.0039380	total: 1.45s	remaining: 5.63s
# 41:	learn: 0.0038693	total: 1.47s	remaining: 5.52s
# 42:	learn: 0.0038595	total: 1.48s	remaining: 5.41s
# 43:	learn: 0.0038038	total: 1.5s	remaining: 5.3s
# 44:	learn: 0.0037801	total: 1.51s	remaining: 5.2s
# 45:	learn: 0.0037660	total: 1.52s	remaining: 5.1s
# 46:	learn: 0.0037222	total: 1.54s	remaining: 5.01s
# 47:	learn: 0.0037123	total: 1.55s	remaining: 4.92s
# 48:	learn: 0.0037025	total: 1.57s	remaining: 4.83s
# 49:	learn: 0.0036882	total: 1.58s	remaining: 4.75s
# 50:	learn: 0.0036714	total: 1.6s	remaining: 4.67s
# 51:	learn: 0.0036625	total: 1.61s	remaining: 4.59s
# 52:	learn: 0.0036536	total: 1.63s	remaining: 4.51s
# 53:	learn: 0.0036136	total: 1.64s	remaining: 4.43s
# 54:	learn: 0.0036090	total: 1.65s	remaining: 4.36s
# 55:	learn: 0.0035772	total: 1.67s	remaining: 4.29s
# 56:	learn: 0.0035527	total: 1.68s	remaining: 4.22s
# 57:	learn: 0.0035469	total: 1.7s	remaining: 4.16s
# 58:	learn: 0.0035081	total: 1.71s	remaining: 4.09s
# 59:	learn: 0.0035019	total: 1.73s	remaining: 4.03s
# 60:	learn: 0.0034936	total: 1.74s	remaining: 3.97s
# 61:	learn: 0.0034429	total: 1.76s	remaining: 3.91s
# 62:	learn: 0.0034377	total: 1.78s	remaining: 3.88s
# 63:	learn: 0.0034175	total: 1.8s	remaining: 3.82s
# 64:	learn: 0.0034006	total: 1.81s	remaining: 3.77s
# 65:	learn: 0.0033862	total: 1.83s	remaining: 3.71s
# 66:	learn: 0.0033612	total: 1.84s	remaining: 3.66s
# 67:	learn: 0.0033418	total: 1.86s	remaining: 3.6s
# 68:	learn: 0.0033295	total: 1.87s	remaining: 3.55s
# 69:	learn: 0.0033249	total: 1.89s	remaining: 3.5s
# 70:	learn: 0.0033000	total: 1.9s	remaining: 3.45s
# 71:	learn: 0.0032871	total: 1.92s	remaining: 3.4s
# 72:	learn: 0.0032773	total: 1.93s	remaining: 3.36s
# 73:	learn: 0.0032582	total: 1.94s	remaining: 3.31s
# 74:	learn: 0.0032547	total: 1.96s	remaining: 3.27s
# 75:	learn: 0.0032345	total: 1.97s	remaining: 3.22s
# 76:	learn: 0.0032311	total: 2s	remaining: 3.2s
# 77:	learn: 0.0032138	total: 2.02s	remaining: 3.15s
# 78:	learn: 0.0032083	total: 2.03s	remaining: 3.11s
# 79:	learn: 0.0031947	total: 2.04s	remaining: 3.07s
# 80:	learn: 0.0031793	total: 2.06s	remaining: 3.02s
# 81:	learn: 0.0031728	total: 2.07s	remaining: 2.98s
# 82:	learn: 0.0031701	total: 2.09s	remaining: 2.94s
# 83:	learn: 0.0031412	total: 2.1s	remaining: 2.9s
# 84:	learn: 0.0031289	total: 2.12s	remaining: 2.86s
# 85:	learn: 0.0031146	total: 2.13s	remaining: 2.82s
# 86:	learn: 0.0031061	total: 2.15s	remaining: 2.79s
# 87:	learn: 0.0030801	total: 2.16s	remaining: 2.75s
# 88:	learn: 0.0030572	total: 2.17s	remaining: 2.71s
# 89:	learn: 0.0030302	total: 2.19s	remaining: 2.68s
# 90:	learn: 0.0030104	total: 2.21s	remaining: 2.65s
# 91:	learn: 0.0029943	total: 2.23s	remaining: 2.61s
# 92:	learn: 0.0029908	total: 2.24s	remaining: 2.58s
# 93:	learn: 0.0029733	total: 2.27s	remaining: 2.56s
# 94:	learn: 0.0029681	total: 2.28s	remaining: 2.52s
# 95:	learn: 0.0029524	total: 2.3s	remaining: 2.49s
# 96:	learn: 0.0029495	total: 2.32s	remaining: 2.46s
# 97:	learn: 0.0029451	total: 2.33s	remaining: 2.43s
# 98:	learn: 0.0029329	total: 2.35s	remaining: 2.39s
# 99:	learn: 0.0029292	total: 2.36s	remaining: 2.36s
# 100:	learn: 0.0029182	total: 2.38s	remaining: 2.33s
# 101:	learn: 0.0029145	total: 2.39s	remaining: 2.3s
# 102:	learn: 0.0029129	total: 2.42s	remaining: 2.27s
# 103:	learn: 0.0029024	total: 2.43s	remaining: 2.24s
# 104:	learn: 0.0028939	total: 2.44s	remaining: 2.21s
# 105:	learn: 0.0028903	total: 2.46s	remaining: 2.18s
# 106:	learn: 0.0028896	total: 2.47s	remaining: 2.15s
# 107:	learn: 0.0028725	total: 2.49s	remaining: 2.12s
# 108:	learn: 0.0028612	total: 2.5s	remaining: 2.09s
# 109:	learn: 0.0028571	total: 2.52s	remaining: 2.06s
# 110:	learn: 0.0028516	total: 2.53s	remaining: 2.03s
# 111:	learn: 0.0028415	total: 2.55s	remaining: 2s
# 112:	learn: 0.0028386	total: 2.56s	remaining: 1.97s
# 113:	learn: 0.0028358	total: 2.58s	remaining: 1.94s
# 114:	learn: 0.0028105	total: 2.59s	remaining: 1.91s
# 115:	learn: 0.0028089	total: 2.6s	remaining: 1.89s
# 116:	learn: 0.0027881	total: 2.63s	remaining: 1.87s
# 117:	learn: 0.0027818	total: 2.65s	remaining: 1.84s
# 118:	learn: 0.0027715	total: 2.66s	remaining: 1.81s
# 119:	learn: 0.0027689	total: 2.67s	remaining: 1.78s
# 120:	learn: 0.0027679	total: 2.69s	remaining: 1.76s
# 121:	learn: 0.0027597	total: 2.7s	remaining: 1.73s
# 122:	learn: 0.0027535	total: 2.72s	remaining: 1.7s
# 123:	learn: 0.0027447	total: 2.73s	remaining: 1.68s
# 124:	learn: 0.0027382	total: 2.75s	remaining: 1.65s
# 125:	learn: 0.0027252	total: 2.76s	remaining: 1.62s
# 126:	learn: 0.0027221	total: 2.78s	remaining: 1.6s
# 127:	learn: 0.0027095	total: 2.79s	remaining: 1.57s
# 128:	learn: 0.0027075	total: 2.81s	remaining: 1.54s
# 129:	learn: 0.0027052	total: 2.82s	remaining: 1.52s
# 130:	learn: 0.0026918	total: 2.85s	remaining: 1.5s
# 131:	learn: 0.0026912	total: 2.86s	remaining: 1.47s
# 132:	learn: 0.0026821	total: 2.87s	remaining: 1.45s
# 133:	learn: 0.0026748	total: 2.89s	remaining: 1.42s
# 134:	learn: 0.0026738	total: 2.91s	remaining: 1.4s
# 135:	learn: 0.0026626	total: 2.93s	remaining: 1.38s
# 136:	learn: 0.0026612	total: 2.94s	remaining: 1.35s
# 137:	learn: 0.0026520	total: 2.96s	remaining: 1.33s
# 138:	learn: 0.0026481	total: 2.97s	remaining: 1.3s
# 139:	learn: 0.0026468	total: 2.99s	remaining: 1.28s
# 140:	learn: 0.0026391	total: 3s	remaining: 1.25s
# 141:	learn: 0.0026357	total: 3.02s	remaining: 1.23s
# 142:	learn: 0.0026297	total: 3.03s	remaining: 1.21s
# 143:	learn: 0.0026234	total: 3.06s	remaining: 1.19s
# 144:	learn: 0.0026200	total: 3.07s	remaining: 1.16s
# 145:	learn: 0.0026188	total: 3.08s	remaining: 1.14s
# 146:	learn: 0.0026177	total: 3.1s	remaining: 1.12s
# 147:	learn: 0.0026095	total: 3.11s	remaining: 1.09s
# 148:	learn: 0.0026088	total: 3.13s	remaining: 1.07s
# 149:	learn: 0.0026033	total: 3.15s	remaining: 1.05s
# 150:	learn: 0.0026016	total: 3.16s	remaining: 1.02s
# 151:	learn: 0.0025985	total: 3.17s	remaining: 1s
# 152:	learn: 0.0025966	total: 3.19s	remaining: 980ms
# 153:	learn: 0.0025846	total: 3.2s	remaining: 957ms
# 154:	learn: 0.0025690	total: 3.22s	remaining: 934ms
# 155:	learn: 0.0025673	total: 3.25s	remaining: 915ms
# 156:	learn: 0.0025579	total: 3.27s	remaining: 896ms
# 157:	learn: 0.0025565	total: 3.29s	remaining: 873ms
# 158:	learn: 0.0025547	total: 3.3s	remaining: 851ms
# 159:	learn: 0.0025498	total: 3.31s	remaining: 829ms
# 160:	learn: 0.0025424	total: 3.33s	remaining: 807ms
# 161:	learn: 0.0025416	total: 3.34s	remaining: 785ms
# 162:	learn: 0.0025364	total: 3.36s	remaining: 763ms
# 163:	learn: 0.0025344	total: 3.37s	remaining: 741ms
# 164:	learn: 0.0025338	total: 3.39s	remaining: 719ms
# 165:	learn: 0.0025313	total: 3.4s	remaining: 697ms
# 166:	learn: 0.0025235	total: 3.42s	remaining: 675ms
# 167:	learn: 0.0025174	total: 3.43s	remaining: 654ms
# 168:	learn: 0.0025167	total: 3.45s	remaining: 634ms
# 169:	learn: 0.0025152	total: 3.48s	remaining: 614ms
# 170:	learn: 0.0025100	total: 3.49s	remaining: 593ms
# 171:	learn: 0.0024991	total: 3.51s	remaining: 571ms
# 172:	learn: 0.0024909	total: 3.52s	remaining: 550ms
# 173:	learn: 0.0024903	total: 3.54s	remaining: 529ms
# 174:	learn: 0.0024892	total: 3.55s	remaining: 507ms
# 175:	learn: 0.0024846	total: 3.57s	remaining: 486ms
# 176:	learn: 0.0024771	total: 3.58s	remaining: 465ms
# 177:	learn: 0.0024760	total: 3.6s	remaining: 444ms
# 178:	learn: 0.0024738	total: 3.61s	remaining: 424ms
# 179:	learn: 0.0024731	total: 3.62s	remaining: 403ms
# 180:	learn: 0.0024693	total: 3.64s	remaining: 382ms
# 181:	learn: 0.0024643	total: 3.65s	remaining: 361ms
# 182:	learn: 0.0024625	total: 3.67s	remaining: 341ms
# 183:	learn: 0.0024616	total: 3.69s	remaining: 321ms
# 184:	learn: 0.0024602	total: 3.71s	remaining: 301ms
# 185:	learn: 0.0024597	total: 3.72s	remaining: 280ms
# 186:	learn: 0.0024552	total: 3.74s	remaining: 260ms
# 187:	learn: 0.0024472	total: 3.75s	remaining: 240ms
# 188:	learn: 0.0024455	total: 3.77s	remaining: 219ms
# 189:	learn: 0.0024436	total: 3.78s	remaining: 199ms
# 190:	learn: 0.0024361	total: 3.8s	remaining: 179ms
# 191:	learn: 0.0024343	total: 3.81s	remaining: 159ms
# 192:	learn: 0.0024303	total: 3.83s	remaining: 139ms
# 193:	learn: 0.0024280	total: 3.84s	remaining: 119ms
# 194:	learn: 0.0024216	total: 3.86s	remaining: 98.9ms
# 195:	learn: 0.0024206	total: 3.87s	remaining: 79ms
# 196:	learn: 0.0024190	total: 3.89s	remaining: 59.2ms
# 197:	learn: 0.0024174	total: 3.9s	remaining: 39.4ms
# 198:	learn: 0.0024162	total: 3.92s	remaining: 19.7ms
# 199:	learn: 0.0024110	total: 3.93s	remaining: 0us
# 0:	learn: 0.3978881	total: 21.6ms	remaining: 4.3s
# 1:	learn: 0.2313909	total: 41.8ms	remaining: 4.13s
# 2:	learn: 0.1404411	total: 62.2ms	remaining: 4.09s
# 3:	learn: 0.0849721	total: 82.9ms	remaining: 4.06s
# 4:	learn: 0.0550006	total: 103ms	remaining: 4.04s
# 5:	learn: 0.0380746	total: 124ms	remaining: 4.01s
# 6:	learn: 0.0278400	total: 145ms	remaining: 3.99s
# 7:	learn: 0.0213835	total: 165ms	remaining: 3.97s
# 8:	learn: 0.0171671	total: 186ms	remaining: 3.95s
# 9:	learn: 0.0141324	total: 207ms	remaining: 3.93s
# 10:	learn: 0.0122848	total: 244ms	remaining: 4.2s
# 11:	learn: 0.0103252	total: 280ms	remaining: 4.38s
# 12:	learn: 0.0089764	total: 301ms	remaining: 4.33s
# 13:	learn: 0.0080607	total: 326ms	remaining: 4.33s
# 14:	learn: 0.0074348	total: 365ms	remaining: 4.51s
# 15:	learn: 0.0068832	total: 391ms	remaining: 4.49s
# 16:	learn: 0.0065637	total: 415ms	remaining: 4.47s
# 17:	learn: 0.0061929	total: 479ms	remaining: 4.85s
# 18:	learn: 0.0060056	total: 536ms	remaining: 5.1s
# 19:	learn: 0.0057596	total: 591ms	remaining: 5.32s
# 20:	learn: 0.0056128	total: 648ms	remaining: 5.52s
# 21:	learn: 0.0054563	total: 703ms	remaining: 5.69s
# 22:	learn: 0.0052545	total: 759ms	remaining: 5.84s
# 23:	learn: 0.0049621	total: 819ms	remaining: 6s
# 24:	learn: 0.0048445	total: 876ms	remaining: 6.13s
# 25:	learn: 0.0046695	total: 936ms	remaining: 6.26s
# 26:	learn: 0.0045122	total: 995ms	remaining: 6.38s
# 27:	learn: 0.0044517	total: 1.05s	remaining: 6.48s
# 28:	learn: 0.0044150	total: 1.11s	remaining: 6.55s
# 29:	learn: 0.0043325	total: 1.17s	remaining: 6.61s
# 30:	learn: 0.0042328	total: 1.22s	remaining: 6.67s
# 31:	learn: 0.0041715	total: 1.28s	remaining: 6.72s
# 32:	learn: 0.0041481	total: 1.33s	remaining: 6.76s
# 33:	learn: 0.0040882	total: 1.39s	remaining: 6.79s
# 34:	learn: 0.0040613	total: 1.45s	remaining: 6.83s
# 35:	learn: 0.0039676	total: 1.51s	remaining: 6.86s
# 36:	learn: 0.0039153	total: 1.56s	remaining: 6.88s
# 37:	learn: 0.0038809	total: 1.62s	remaining: 6.91s
# 38:	learn: 0.0038614	total: 1.68s	remaining: 6.92s
# 39:	learn: 0.0038332	total: 1.73s	remaining: 6.93s
# 40:	learn: 0.0037860	total: 1.79s	remaining: 6.94s
# 41:	learn: 0.0037538	total: 1.86s	remaining: 6.99s
# 42:	learn: 0.0037341	total: 1.91s	remaining: 6.99s
# 43:	learn: 0.0037032	total: 1.97s	remaining: 6.99s
# 44:	learn: 0.0036945	total: 2.03s	remaining: 6.98s
# 45:	learn: 0.0036663	total: 2.09s	remaining: 6.99s
# 46:	learn: 0.0036504	total: 2.14s	remaining: 6.98s
# 47:	learn: 0.0036040	total: 2.2s	remaining: 6.97s
# 48:	learn: 0.0035950	total: 2.26s	remaining: 6.96s
# 49:	learn: 0.0035783	total: 2.33s	remaining: 6.98s
# 50:	learn: 0.0035658	total: 2.39s	remaining: 6.98s
# 51:	learn: 0.0035508	total: 2.45s	remaining: 6.97s
# 52:	learn: 0.0035442	total: 2.51s	remaining: 6.96s
# 53:	learn: 0.0035315	total: 2.58s	remaining: 6.96s
# 54:	learn: 0.0035055	total: 2.64s	remaining: 6.95s
# 55:	learn: 0.0034986	total: 2.7s	remaining: 6.94s
# 56:	learn: 0.0034938	total: 2.76s	remaining: 6.93s
# 57:	learn: 0.0034838	total: 2.83s	remaining: 6.92s
# 58:	learn: 0.0034783	total: 2.9s	remaining: 6.92s
# 59:	learn: 0.0034601	total: 2.96s	remaining: 6.91s
# 60:	learn: 0.0034381	total: 3s	remaining: 6.84s
# 61:	learn: 0.0034023	total: 3.04s	remaining: 6.77s
# 62:	learn: 0.0033829	total: 3.08s	remaining: 6.7s
# 63:	learn: 0.0033661	total: 3.11s	remaining: 6.62s
# 64:	learn: 0.0033532	total: 3.16s	remaining: 6.57s
# 65:	learn: 0.0033379	total: 3.22s	remaining: 6.55s
# 66:	learn: 0.0033333	total: 3.29s	remaining: 6.54s
# 67:	learn: 0.0032903	total: 3.35s	remaining: 6.51s
# 68:	learn: 0.0032858	total: 3.42s	remaining: 6.49s
# 69:	learn: 0.0032822	total: 3.47s	remaining: 6.45s
# 70:	learn: 0.0032466	total: 3.52s	remaining: 6.4s
# 71:	learn: 0.0032354	total: 3.54s	remaining: 6.3s
# 72:	learn: 0.0032292	total: 3.56s	remaining: 6.2s
# 73:	learn: 0.0032235	total: 3.58s	remaining: 6.1s
# 74:	learn: 0.0032161	total: 3.6s	remaining: 6s
# 75:	learn: 0.0032049	total: 3.62s	remaining: 5.91s
# 76:	learn: 0.0031991	total: 3.64s	remaining: 5.81s
# 77:	learn: 0.0031765	total: 3.65s	remaining: 5.72s
# 78:	learn: 0.0031682	total: 3.67s	remaining: 5.62s
# 79:	learn: 0.0031622	total: 3.69s	remaining: 5.53s
# 80:	learn: 0.0031568	total: 3.71s	remaining: 5.45s
# 81:	learn: 0.0031346	total: 3.74s	remaining: 5.38s
# 82:	learn: 0.0031144	total: 3.76s	remaining: 5.3s
# 83:	learn: 0.0031127	total: 3.78s	remaining: 5.21s
# 84:	learn: 0.0030972	total: 3.79s	remaining: 5.13s
# 85:	learn: 0.0030900	total: 3.81s	remaining: 5.05s
# 86:	learn: 0.0030835	total: 3.82s	remaining: 4.97s
# 87:	learn: 0.0030772	total: 3.84s	remaining: 4.89s
# 88:	learn: 0.0030620	total: 3.85s	remaining: 4.81s
# 89:	learn: 0.0030561	total: 3.88s	remaining: 4.74s
# 90:	learn: 0.0030367	total: 3.89s	remaining: 4.66s
# 91:	learn: 0.0030213	total: 3.91s	remaining: 4.59s
# 92:	learn: 0.0030018	total: 3.92s	remaining: 4.52s
# 93:	learn: 0.0029863	total: 3.95s	remaining: 4.46s
# 94:	learn: 0.0029810	total: 3.97s	remaining: 4.39s
# 95:	learn: 0.0029774	total: 3.98s	remaining: 4.32s
# 96:	learn: 0.0029717	total: 4s	remaining: 4.24s
# 97:	learn: 0.0029693	total: 4.01s	remaining: 4.17s
# 98:	learn: 0.0029583	total: 4.03s	remaining: 4.11s
# 99:	learn: 0.0029479	total: 4.04s	remaining: 4.04s
# 100:	learn: 0.0029399	total: 4.06s	remaining: 3.98s
# 101:	learn: 0.0029220	total: 4.07s	remaining: 3.91s
# 102:	learn: 0.0029188	total: 4.09s	remaining: 3.85s
# 103:	learn: 0.0029058	total: 4.1s	remaining: 3.79s
# 104:	learn: 0.0029012	total: 4.12s	remaining: 3.72s
# 105:	learn: 0.0028894	total: 4.13s	remaining: 3.66s
# 106:	learn: 0.0028840	total: 4.14s	remaining: 3.6s
# 107:	learn: 0.0028678	total: 4.17s	remaining: 3.55s
# 108:	learn: 0.0028568	total: 4.18s	remaining: 3.49s
# 109:	learn: 0.0028508	total: 4.2s	remaining: 3.43s
# 110:	learn: 0.0028494	total: 4.21s	remaining: 3.38s
# 111:	learn: 0.0028478	total: 4.23s	remaining: 3.32s
# 112:	learn: 0.0028389	total: 4.24s	remaining: 3.27s
# 113:	learn: 0.0028249	total: 4.25s	remaining: 3.21s
# 114:	learn: 0.0028163	total: 4.27s	remaining: 3.16s
# 115:	learn: 0.0028132	total: 4.28s	remaining: 3.1s
# 116:	learn: 0.0028117	total: 4.3s	remaining: 3.05s
# 117:	learn: 0.0028100	total: 4.31s	remaining: 3s
# 118:	learn: 0.0028068	total: 4.33s	remaining: 2.94s
# 119:	learn: 0.0028003	total: 4.34s	remaining: 2.89s
# 120:	learn: 0.0027926	total: 4.36s	remaining: 2.84s
# 121:	learn: 0.0027715	total: 4.38s	remaining: 2.8s
# 122:	learn: 0.0027684	total: 4.4s	remaining: 2.75s
# 123:	learn: 0.0027655	total: 4.42s	remaining: 2.71s
# 124:	learn: 0.0027602	total: 4.45s	remaining: 2.67s
# 125:	learn: 0.0027576	total: 4.46s	remaining: 2.62s
# 126:	learn: 0.0027395	total: 4.48s	remaining: 2.57s
# 127:	learn: 0.0027378	total: 4.49s	remaining: 2.53s
# 128:	learn: 0.0027359	total: 4.51s	remaining: 2.48s
# 129:	learn: 0.0027327	total: 4.52s	remaining: 2.43s
# 130:	learn: 0.0027316	total: 4.54s	remaining: 2.39s
# 131:	learn: 0.0027299	total: 4.55s	remaining: 2.34s
# 132:	learn: 0.0027249	total: 4.57s	remaining: 2.3s
# 133:	learn: 0.0027122	total: 4.59s	remaining: 2.26s
# 134:	learn: 0.0027112	total: 4.61s	remaining: 2.22s
# 135:	learn: 0.0027079	total: 4.64s	remaining: 2.18s
# 136:	learn: 0.0027059	total: 4.66s	remaining: 2.14s
# 137:	learn: 0.0027017	total: 4.69s	remaining: 2.11s
# 138:	learn: 0.0026996	total: 4.72s	remaining: 2.07s
# 139:	learn: 0.0026958	total: 4.78s	remaining: 2.05s
# 140:	learn: 0.0026810	total: 4.83s	remaining: 2.02s
# 141:	learn: 0.0026790	total: 4.89s	remaining: 2s
# 142:	learn: 0.0026764	total: 4.94s	remaining: 1.97s
# 143:	learn: 0.0026744	total: 5s	remaining: 1.94s
# 144:	learn: 0.0026712	total: 5.05s	remaining: 1.92s
# 145:	learn: 0.0026587	total: 5.11s	remaining: 1.89s
# 146:	learn: 0.0026517	total: 5.16s	remaining: 1.86s
# 147:	learn: 0.0026479	total: 5.21s	remaining: 1.83s
# 148:	learn: 0.0026455	total: 5.27s	remaining: 1.8s
# 149:	learn: 0.0026413	total: 5.32s	remaining: 1.77s
# 150:	learn: 0.0026282	total: 5.38s	remaining: 1.74s
# 151:	learn: 0.0026269	total: 5.43s	remaining: 1.71s
# 152:	learn: 0.0026164	total: 5.49s	remaining: 1.69s
# 153:	learn: 0.0026152	total: 5.54s	remaining: 1.65s
# 154:	learn: 0.0026131	total: 5.59s	remaining: 1.62s
# 155:	learn: 0.0026100	total: 5.65s	remaining: 1.59s
# 156:	learn: 0.0026076	total: 5.71s	remaining: 1.56s
# 157:	learn: 0.0026012	total: 5.76s	remaining: 1.53s
# 158:	learn: 0.0025997	total: 5.82s	remaining: 1.5s
# 159:	learn: 0.0025982	total: 5.88s	remaining: 1.47s
# 160:	learn: 0.0025953	total: 5.94s	remaining: 1.44s
# 161:	learn: 0.0025887	total: 6s	remaining: 1.41s
# 162:	learn: 0.0025861	total: 6.05s	remaining: 1.37s
# 163:	learn: 0.0025829	total: 6.11s	remaining: 1.34s
# 164:	learn: 0.0025814	total: 6.16s	remaining: 1.31s
# 165:	learn: 0.0025803	total: 6.22s	remaining: 1.27s
# 166:	learn: 0.0025715	total: 6.28s	remaining: 1.24s
# 167:	learn: 0.0025682	total: 6.34s	remaining: 1.21s
# 168:	learn: 0.0025593	total: 6.4s	remaining: 1.17s
# 169:	learn: 0.0025544	total: 6.45s	remaining: 1.14s
# 170:	learn: 0.0025514	total: 6.5s	remaining: 1.1s
# 171:	learn: 0.0025352	total: 6.57s	remaining: 1.07s
# 172:	learn: 0.0025340	total: 6.63s	remaining: 1.03s
# 173:	learn: 0.0025322	total: 6.69s	remaining: 1000ms
# 174:	learn: 0.0025304	total: 6.75s	remaining: 964ms
# 175:	learn: 0.0025170	total: 6.81s	remaining: 929ms
# 176:	learn: 0.0025150	total: 6.88s	remaining: 894ms
# 177:	learn: 0.0025106	total: 6.95s	remaining: 859ms
# 178:	learn: 0.0025036	total: 7s	remaining: 822ms
# 179:	learn: 0.0024926	total: 7.07s	remaining: 786ms
# 180:	learn: 0.0024912	total: 7.13s	remaining: 749ms
# 181:	learn: 0.0024897	total: 7.19s	remaining: 711ms
# 182:	learn: 0.0024862	total: 7.25s	remaining: 674ms
# 183:	learn: 0.0024838	total: 7.31s	remaining: 636ms
# 184:	learn: 0.0024766	total: 7.37s	remaining: 598ms
# 185:	learn: 0.0024689	total: 7.43s	remaining: 560ms
# 186:	learn: 0.0024629	total: 7.49s	remaining: 520ms
# 187:	learn: 0.0024622	total: 7.55s	remaining: 482ms
# 188:	learn: 0.0024551	total: 7.61s	remaining: 443ms
# 189:	learn: 0.0024448	total: 7.67s	remaining: 404ms
# 190:	learn: 0.0024435	total: 7.73s	remaining: 364ms
# 191:	learn: 0.0024415	total: 7.79s	remaining: 324ms
# 192:	learn: 0.0024404	total: 7.81s	remaining: 283ms
# 193:	learn: 0.0024313	total: 7.83s	remaining: 242ms
# 194:	learn: 0.0024300	total: 7.85s	remaining: 201ms
# 195:	learn: 0.0024177	total: 7.87s	remaining: 161ms
# 196:	learn: 0.0024158	total: 7.88s	remaining: 120ms
# 197:	learn: 0.0024150	total: 7.9s	remaining: 79.8ms
# 198:	learn: 0.0024115	total: 7.92s	remaining: 39.8ms
# 199:	learn: 0.0024024	total: 7.95s	remaining: 0us
# 0:	learn: 0.3936877	total: 29ms	remaining: 5.76s
# 1:	learn: 0.2153591	total: 95.4ms	remaining: 9.44s
# 2:	learn: 0.1162951	total: 165ms	remaining: 10.8s
# 3:	learn: 0.0617049	total: 225ms	remaining: 11s
# 4:	learn: 0.0358610	total: 295ms	remaining: 11.5s
# 5:	learn: 0.0227853	total: 335ms	remaining: 10.8s
# 6:	learn: 0.0156678	total: 373ms	remaining: 10.3s
# 7:	learn: 0.0110305	total: 412ms	remaining: 9.88s
# 8:	learn: 0.0087220	total: 449ms	remaining: 9.54s
# 9:	learn: 0.0072336	total: 487ms	remaining: 9.26s
# 10:	learn: 0.0062229	total: 534ms	remaining: 9.17s
# 11:	learn: 0.0054331	total: 571ms	remaining: 8.94s
# 12:	learn: 0.0048231	total: 607ms	remaining: 8.74s
# 13:	learn: 0.0045409	total: 645ms	remaining: 8.56s
# 14:	learn: 0.0042136	total: 683ms	remaining: 8.42s
# 15:	learn: 0.0040871	total: 719ms	remaining: 8.27s
# 16:	learn: 0.0040065	total: 765ms	remaining: 8.24s
# 17:	learn: 0.0039157	total: 801ms	remaining: 8.1s
# 18:	learn: 0.0037462	total: 837ms	remaining: 7.97s
# 19:	learn: 0.0036815	total: 874ms	remaining: 7.87s
# 20:	learn: 0.0036215	total: 911ms	remaining: 7.76s
# 21:	learn: 0.0035169	total: 947ms	remaining: 7.66s
# 22:	learn: 0.0034599	total: 994ms	remaining: 7.65s
# 23:	learn: 0.0033942	total: 1.03s	remaining: 7.56s
# 24:	learn: 0.0033414	total: 1.07s	remaining: 7.49s
# 25:	learn: 0.0033042	total: 1.11s	remaining: 7.41s
# 26:	learn: 0.0032247	total: 1.14s	remaining: 7.33s
# 27:	learn: 0.0031991	total: 1.2s	remaining: 7.4s
# 28:	learn: 0.0031618	total: 1.24s	remaining: 7.32s
# 29:	learn: 0.0031431	total: 1.28s	remaining: 7.24s
# 30:	learn: 0.0031124	total: 1.31s	remaining: 7.17s
# 31:	learn: 0.0030653	total: 1.35s	remaining: 7.09s
# 32:	learn: 0.0030227	total: 1.39s	remaining: 7.03s
# 33:	learn: 0.0029924	total: 1.44s	remaining: 7.01s
# 34:	learn: 0.0029674	total: 1.47s	remaining: 6.95s
# 35:	learn: 0.0029323	total: 1.51s	remaining: 6.89s
# 36:	learn: 0.0028917	total: 1.55s	remaining: 6.82s
# 37:	learn: 0.0028378	total: 1.59s	remaining: 6.8s
# 38:	learn: 0.0028135	total: 1.63s	remaining: 6.73s
# 39:	learn: 0.0027994	total: 1.68s	remaining: 6.71s
# 40:	learn: 0.0027727	total: 1.71s	remaining: 6.65s
# 41:	learn: 0.0027452	total: 1.75s	remaining: 6.59s
# 42:	learn: 0.0027203	total: 1.79s	remaining: 6.53s
# 43:	learn: 0.0026954	total: 1.82s	remaining: 6.47s
# 44:	learn: 0.0026728	total: 1.86s	remaining: 6.41s
# 45:	learn: 0.0026534	total: 1.91s	remaining: 6.41s
# 46:	learn: 0.0026308	total: 1.95s	remaining: 6.36s
# 47:	learn: 0.0026129	total: 1.99s	remaining: 6.29s
# 48:	learn: 0.0026065	total: 2.02s	remaining: 6.24s
# 49:	learn: 0.0025887	total: 2.06s	remaining: 6.19s
# 50:	learn: 0.0025791	total: 2.1s	remaining: 6.13s
# 51:	learn: 0.0025610	total: 2.15s	remaining: 6.13s
# 52:	learn: 0.0025562	total: 2.19s	remaining: 6.09s
# 53:	learn: 0.0025424	total: 2.23s	remaining: 6.04s
# 54:	learn: 0.0025269	total: 2.27s	remaining: 5.99s
# 55:	learn: 0.0025121	total: 2.32s	remaining: 5.96s
# 56:	learn: 0.0024975	total: 2.36s	remaining: 5.93s
# 57:	learn: 0.0024843	total: 2.4s	remaining: 5.88s
# 58:	learn: 0.0024711	total: 2.44s	remaining: 5.83s
# 59:	learn: 0.0024630	total: 2.48s	remaining: 5.78s
# 60:	learn: 0.0024416	total: 2.52s	remaining: 5.73s
# 61:	learn: 0.0024312	total: 2.55s	remaining: 5.68s
# 62:	learn: 0.0024272	total: 2.6s	remaining: 5.65s
# 63:	learn: 0.0024193	total: 2.64s	remaining: 5.6s
# 64:	learn: 0.0024060	total: 2.67s	remaining: 5.55s
# 65:	learn: 0.0023821	total: 2.71s	remaining: 5.5s
# 66:	learn: 0.0023718	total: 2.75s	remaining: 5.46s
# 67:	learn: 0.0023557	total: 2.79s	remaining: 5.41s
# 68:	learn: 0.0023449	total: 2.83s	remaining: 5.38s
# 69:	learn: 0.0023304	total: 2.87s	remaining: 5.33s
# 70:	learn: 0.0023148	total: 2.91s	remaining: 5.29s
# 71:	learn: 0.0023117	total: 2.95s	remaining: 5.24s
# 72:	learn: 0.0023016	total: 2.98s	remaining: 5.19s
# 73:	learn: 0.0022805	total: 3.02s	remaining: 5.15s
# 74:	learn: 0.0022720	total: 3.07s	remaining: 5.12s
# 75:	learn: 0.0022671	total: 3.11s	remaining: 5.07s
# 76:	learn: 0.0022629	total: 3.14s	remaining: 5.02s
# 77:	learn: 0.0022562	total: 3.19s	remaining: 4.99s
# 78:	learn: 0.0022394	total: 3.23s	remaining: 4.95s
# 79:	learn: 0.0022243	total: 3.27s	remaining: 4.9s
# 80:	learn: 0.0022184	total: 3.31s	remaining: 4.87s
# 81:	learn: 0.0022102	total: 3.35s	remaining: 4.83s
# 82:	learn: 0.0021961	total: 3.39s	remaining: 4.78s
# 83:	learn: 0.0021834	total: 3.43s	remaining: 4.73s
# 84:	learn: 0.0021727	total: 3.46s	remaining: 4.69s
# 85:	learn: 0.0021623	total: 3.51s	remaining: 4.65s
# 86:	learn: 0.0021544	total: 3.56s	remaining: 4.62s
# 87:	learn: 0.0021486	total: 3.59s	remaining: 4.57s
# 88:	learn: 0.0021399	total: 3.63s	remaining: 4.53s
# 89:	learn: 0.0021307	total: 3.67s	remaining: 4.49s
# 90:	learn: 0.0021238	total: 3.71s	remaining: 4.44s
# 91:	learn: 0.0021181	total: 3.75s	remaining: 4.4s
# 92:	learn: 0.0021020	total: 3.79s	remaining: 4.36s
# 93:	learn: 0.0020938	total: 3.83s	remaining: 4.32s
# 94:	learn: 0.0020864	total: 3.87s	remaining: 4.27s
# 95:	learn: 0.0020749	total: 3.9s	remaining: 4.23s
# 96:	learn: 0.0020706	total: 3.94s	remaining: 4.19s
# 97:	learn: 0.0020615	total: 3.98s	remaining: 4.14s
# 98:	learn: 0.0020599	total: 4.03s	remaining: 4.11s
# 99:	learn: 0.0020560	total: 4.06s	remaining: 4.06s
# 100:	learn: 0.0020491	total: 4.1s	remaining: 4.02s
# 101:	learn: 0.0020420	total: 4.14s	remaining: 3.98s
# 102:	learn: 0.0020372	total: 4.19s	remaining: 3.94s
# 103:	learn: 0.0020337	total: 4.24s	remaining: 3.91s
# 104:	learn: 0.0020248	total: 4.28s	remaining: 3.87s
# 105:	learn: 0.0020193	total: 4.31s	remaining: 3.83s
# 106:	learn: 0.0020124	total: 4.35s	remaining: 3.78s
# 107:	learn: 0.0020118	total: 4.36s	remaining: 3.72s
# 108:	learn: 0.0020064	total: 4.4s	remaining: 3.67s
# 109:	learn: 0.0019982	total: 4.45s	remaining: 3.64s
# 110:	learn: 0.0019903	total: 4.49s	remaining: 3.6s
# 111:	learn: 0.0019844	total: 4.53s	remaining: 3.56s
# 112:	learn: 0.0019747	total: 4.56s	remaining: 3.51s
# 113:	learn: 0.0019679	total: 4.6s	remaining: 3.47s
# 114:	learn: 0.0019622	total: 4.64s	remaining: 3.43s
# 115:	learn: 0.0019579	total: 4.69s	remaining: 3.39s
# 116:	learn: 0.0019519	total: 4.72s	remaining: 3.35s
# 117:	learn: 0.0019484	total: 4.76s	remaining: 3.31s
# 118:	learn: 0.0019449	total: 4.81s	remaining: 3.27s
# 119:	learn: 0.0019415	total: 4.84s	remaining: 3.23s
# 120:	learn: 0.0019359	total: 4.9s	remaining: 3.2s
# 121:	learn: 0.0019307	total: 4.94s	remaining: 3.16s
# 122:	learn: 0.0019255	total: 4.98s	remaining: 3.12s
# 123:	learn: 0.0019215	total: 5.02s	remaining: 3.08s
# 124:	learn: 0.0019151	total: 5.06s	remaining: 3.03s
# 125:	learn: 0.0019097	total: 5.09s	remaining: 2.99s
# 126:	learn: 0.0019017	total: 5.14s	remaining: 2.96s
# 127:	learn: 0.0018959	total: 5.19s	remaining: 2.92s
# 128:	learn: 0.0018900	total: 5.22s	remaining: 2.87s
# 129:	learn: 0.0018866	total: 5.26s	remaining: 2.83s
# 130:	learn: 0.0018797	total: 5.3s	remaining: 2.79s
# 131:	learn: 0.0018764	total: 5.33s	remaining: 2.75s
# 132:	learn: 0.0018696	total: 5.38s	remaining: 2.71s
# 133:	learn: 0.0018662	total: 5.42s	remaining: 2.67s
# 134:	learn: 0.0018610	total: 5.46s	remaining: 2.63s
# 135:	learn: 0.0018564	total: 5.5s	remaining: 2.59s
# 136:	learn: 0.0018534	total: 5.54s	remaining: 2.55s
# 137:	learn: 0.0018488	total: 5.59s	remaining: 2.51s
# 138:	learn: 0.0018421	total: 5.63s	remaining: 2.47s
# 139:	learn: 0.0018381	total: 5.67s	remaining: 2.43s
# 140:	learn: 0.0018360	total: 5.71s	remaining: 2.39s
# 141:	learn: 0.0018333	total: 5.75s	remaining: 2.35s
# 142:	learn: 0.0018297	total: 5.78s	remaining: 2.31s
# 143:	learn: 0.0018257	total: 5.83s	remaining: 2.27s
# 144:	learn: 0.0018221	total: 5.87s	remaining: 2.23s
# 145:	learn: 0.0018160	total: 5.91s	remaining: 2.18s
# 146:	learn: 0.0018086	total: 5.95s	remaining: 2.15s
# 147:	learn: 0.0018043	total: 5.99s	remaining: 2.1s
# 148:	learn: 0.0018015	total: 6.03s	remaining: 2.06s
# 149:	learn: 0.0018001	total: 6.07s	remaining: 2.02s
# 150:	learn: 0.0017943	total: 6.11s	remaining: 1.98s
# 151:	learn: 0.0017911	total: 6.15s	remaining: 1.94s
# 152:	learn: 0.0017871	total: 6.2s	remaining: 1.9s
# 153:	learn: 0.0017843	total: 6.23s	remaining: 1.86s
# 154:	learn: 0.0017798	total: 6.28s	remaining: 1.82s
# 155:	learn: 0.0017755	total: 6.33s	remaining: 1.78s
# 156:	learn: 0.0017720	total: 6.37s	remaining: 1.74s
# 157:	learn: 0.0017687	total: 6.41s	remaining: 1.7s
# 158:	learn: 0.0017644	total: 6.44s	remaining: 1.66s
# 159:	learn: 0.0017615	total: 6.48s	remaining: 1.62s
# 160:	learn: 0.0017542	total: 6.53s	remaining: 1.58s
# 161:	learn: 0.0017515	total: 6.57s	remaining: 1.54s
# 162:	learn: 0.0017467	total: 6.6s	remaining: 1.5s
# 163:	learn: 0.0017419	total: 6.64s	remaining: 1.46s
# 164:	learn: 0.0017383	total: 6.68s	remaining: 1.42s
# 165:	learn: 0.0017321	total: 6.72s	remaining: 1.38s
# 166:	learn: 0.0017299	total: 6.76s	remaining: 1.33s
# 167:	learn: 0.0017251	total: 6.8s	remaining: 1.29s
# 168:	learn: 0.0017215	total: 6.83s	remaining: 1.25s
# 169:	learn: 0.0017168	total: 6.87s	remaining: 1.21s
# 170:	learn: 0.0017131	total: 6.92s	remaining: 1.17s
# 171:	learn: 0.0017089	total: 6.96s	remaining: 1.13s
# 172:	learn: 0.0017009	total: 7s	remaining: 1.09s
# 173:	learn: 0.0016977	total: 7.04s	remaining: 1.05s
# 174:	learn: 0.0016944	total: 7.08s	remaining: 1.01s
# 175:	learn: 0.0016890	total: 7.12s	remaining: 971ms
# 176:	learn: 0.0016858	total: 7.17s	remaining: 931ms
# 177:	learn: 0.0016833	total: 7.21s	remaining: 891ms
# 178:	learn: 0.0016812	total: 7.25s	remaining: 850ms
# 179:	learn: 0.0016780	total: 7.29s	remaining: 810ms
# 180:	learn: 0.0016758	total: 7.32s	remaining: 769ms
# 181:	learn: 0.0016723	total: 7.36s	remaining: 728ms
# 182:	learn: 0.0016689	total: 7.4s	remaining: 688ms
# 183:	learn: 0.0016646	total: 7.45s	remaining: 648ms
# 184:	learn: 0.0016613	total: 7.49s	remaining: 607ms
# 185:	learn: 0.0016597	total: 7.53s	remaining: 567ms
# 186:	learn: 0.0016582	total: 7.57s	remaining: 526ms
# 187:	learn: 0.0016543	total: 7.61s	remaining: 486ms
# 188:	learn: 0.0016516	total: 7.65s	remaining: 445ms
# 189:	learn: 0.0016472	total: 7.69s	remaining: 405ms
# 190:	learn: 0.0016426	total: 7.73s	remaining: 364ms
# 191:	learn: 0.0016389	total: 7.76s	remaining: 324ms
# 192:	learn: 0.0016356	total: 7.8s	remaining: 283ms
# 193:	learn: 0.0016290	total: 7.84s	remaining: 243ms
# 194:	learn: 0.0016251	total: 7.88s	remaining: 202ms
# 195:	learn: 0.0016231	total: 7.92s	remaining: 162ms
# 196:	learn: 0.0016202	total: 7.96s	remaining: 121ms
# 197:	learn: 0.0016181	total: 8s	remaining: 80.8ms
# 198:	learn: 0.0016153	total: 8.04s	remaining: 40.4ms
# 199:	learn: 0.0016116	total: 8.08s	remaining: 0us
# 0:	learn: 0.3939688	total: 27.9ms	remaining: 5.56s
# 1:	learn: 0.2190181	total: 68.7ms	remaining: 6.8s
# 2:	learn: 0.1212496	total: 132ms	remaining: 8.66s
# 3:	learn: 0.0688088	total: 205ms	remaining: 10.1s
# 4:	learn: 0.0424841	total: 268ms	remaining: 10.4s
# 5:	learn: 0.0262449	total: 312ms	remaining: 10.1s
# 6:	learn: 0.0177101	total: 359ms	remaining: 9.89s
# 7:	learn: 0.0116575	total: 403ms	remaining: 9.67s
# 8:	learn: 0.0089910	total: 444ms	remaining: 9.42s
# 9:	learn: 0.0071646	total: 488ms	remaining: 9.26s
# 10:	learn: 0.0059001	total: 524ms	remaining: 9.01s
# 11:	learn: 0.0051285	total: 561ms	remaining: 8.79s
# 12:	learn: 0.0045708	total: 599ms	remaining: 8.62s
# 13:	learn: 0.0041587	total: 637ms	remaining: 8.46s
# 14:	learn: 0.0040266	total: 677ms	remaining: 8.35s
# 15:	learn: 0.0039221	total: 726ms	remaining: 8.35s
# 16:	learn: 0.0038217	total: 764ms	remaining: 8.23s
# 17:	learn: 0.0036853	total: 801ms	remaining: 8.1s
# 18:	learn: 0.0035192	total: 839ms	remaining: 8s
# 19:	learn: 0.0034481	total: 877ms	remaining: 7.89s
# 20:	learn: 0.0033468	total: 913ms	remaining: 7.78s
# 21:	learn: 0.0032550	total: 959ms	remaining: 7.76s
# 22:	learn: 0.0032002	total: 996ms	remaining: 7.67s
# 23:	learn: 0.0031589	total: 1.03s	remaining: 7.59s
# 24:	learn: 0.0031108	total: 1.07s	remaining: 7.5s
# 25:	learn: 0.0030671	total: 1.11s	remaining: 7.42s
# 26:	learn: 0.0030278	total: 1.15s	remaining: 7.34s
# 27:	learn: 0.0030132	total: 1.2s	remaining: 7.37s
# 28:	learn: 0.0029652	total: 1.25s	remaining: 7.34s
# 29:	learn: 0.0029336	total: 1.28s	remaining: 7.26s
# 30:	learn: 0.0029132	total: 1.32s	remaining: 7.18s
# 31:	learn: 0.0028872	total: 1.35s	remaining: 7.11s
# 32:	learn: 0.0028544	total: 1.39s	remaining: 7.04s
# 33:	learn: 0.0028212	total: 1.44s	remaining: 7.03s
# 34:	learn: 0.0028094	total: 1.48s	remaining: 6.96s
# 35:	learn: 0.0027803	total: 1.51s	remaining: 6.9s
# 36:	learn: 0.0027561	total: 1.55s	remaining: 6.84s
# 37:	learn: 0.0027351	total: 1.59s	remaining: 6.78s
# 38:	learn: 0.0027092	total: 1.63s	remaining: 6.72s
# 39:	learn: 0.0026842	total: 1.68s	remaining: 6.72s
# 40:	learn: 0.0026617	total: 1.72s	remaining: 6.66s
# 41:	learn: 0.0026408	total: 1.75s	remaining: 6.6s
# 42:	learn: 0.0026297	total: 1.8s	remaining: 6.56s
# 43:	learn: 0.0026060	total: 1.84s	remaining: 6.54s
# 44:	learn: 0.0025929	total: 1.9s	remaining: 6.54s
# 45:	learn: 0.0025659	total: 1.94s	remaining: 6.49s
# 46:	learn: 0.0025491	total: 1.97s	remaining: 6.43s
# 47:	learn: 0.0025357	total: 2.01s	remaining: 6.38s
# 48:	learn: 0.0025199	total: 2.05s	remaining: 6.33s
# 49:	learn: 0.0025044	total: 2.09s	remaining: 6.27s
# 50:	learn: 0.0024804	total: 2.13s	remaining: 6.24s
# 51:	learn: 0.0024576	total: 2.17s	remaining: 6.18s
# 52:	learn: 0.0024388	total: 2.22s	remaining: 6.17s
# 53:	learn: 0.0024257	total: 2.26s	remaining: 6.11s
# 54:	learn: 0.0024133	total: 2.3s	remaining: 6.06s
# 55:	learn: 0.0023927	total: 2.34s	remaining: 6.02s
# 56:	learn: 0.0023831	total: 2.38s	remaining: 5.97s
# 57:	learn: 0.0023735	total: 2.42s	remaining: 5.92s
# 58:	learn: 0.0023558	total: 2.46s	remaining: 5.87s
# 59:	learn: 0.0023370	total: 2.5s	remaining: 5.82s
# 60:	learn: 0.0023112	total: 2.53s	remaining: 5.77s
# 61:	learn: 0.0023035	total: 2.58s	remaining: 5.74s
# 62:	learn: 0.0022939	total: 2.62s	remaining: 5.69s
# 63:	learn: 0.0022848	total: 2.65s	remaining: 5.64s
# 64:	learn: 0.0022625	total: 2.69s	remaining: 5.59s
# 65:	learn: 0.0022515	total: 2.73s	remaining: 5.54s
# 66:	learn: 0.0022345	total: 2.77s	remaining: 5.5s
# 67:	learn: 0.0022236	total: 2.82s	remaining: 5.47s
# 68:	learn: 0.0022122	total: 2.86s	remaining: 5.42s
# 69:	learn: 0.0022048	total: 2.89s	remaining: 5.37s
# 70:	learn: 0.0021800	total: 2.93s	remaining: 5.33s
# 71:	learn: 0.0021640	total: 2.97s	remaining: 5.28s
# 72:	learn: 0.0021603	total: 3.01s	remaining: 5.23s
# 73:	learn: 0.0021475	total: 3.05s	remaining: 5.2s
# 74:	learn: 0.0021395	total: 3.09s	remaining: 5.15s
# 75:	learn: 0.0021303	total: 3.13s	remaining: 5.1s
# 76:	learn: 0.0021207	total: 3.16s	remaining: 5.05s
# 77:	learn: 0.0021132	total: 3.21s	remaining: 5.03s
# 78:	learn: 0.0021104	total: 3.25s	remaining: 4.98s
# 79:	learn: 0.0021042	total: 3.29s	remaining: 4.93s
# 80:	learn: 0.0020981	total: 3.33s	remaining: 4.89s
# 81:	learn: 0.0020825	total: 3.37s	remaining: 4.85s
# 82:	learn: 0.0020670	total: 3.41s	remaining: 4.8s
# 83:	learn: 0.0020622	total: 3.45s	remaining: 4.76s
# 84:	learn: 0.0020521	total: 3.5s	remaining: 4.74s
# 85:	learn: 0.0020489	total: 3.54s	remaining: 4.69s
# 86:	learn: 0.0020455	total: 3.58s	remaining: 4.65s
# 87:	learn: 0.0020380	total: 3.62s	remaining: 4.6s
# 88:	learn: 0.0020285	total: 3.65s	remaining: 4.56s
# 89:	learn: 0.0020163	total: 3.69s	remaining: 4.51s
# 90:	learn: 0.0020073	total: 3.74s	remaining: 4.48s
# 91:	learn: 0.0020012	total: 3.78s	remaining: 4.44s
# 92:	learn: 0.0019966	total: 3.82s	remaining: 4.39s
# 93:	learn: 0.0019854	total: 3.85s	remaining: 4.35s
# 94:	learn: 0.0019817	total: 3.9s	remaining: 4.32s
# 95:	learn: 0.0019744	total: 3.97s	remaining: 4.3s
# 96:	learn: 0.0019694	total: 4.01s	remaining: 4.25s
# 97:	learn: 0.0019594	total: 4.04s	remaining: 4.21s
# 98:	learn: 0.0019504	total: 4.08s	remaining: 4.16s
# 99:	learn: 0.0019438	total: 4.12s	remaining: 4.12s
# 100:	learn: 0.0019374	total: 4.16s	remaining: 4.07s
# 101:	learn: 0.0019337	total: 4.21s	remaining: 4.05s
# 102:	learn: 0.0019261	total: 4.25s	remaining: 4s
# 103:	learn: 0.0019215	total: 4.29s	remaining: 3.96s
# 104:	learn: 0.0019175	total: 4.33s	remaining: 3.91s
# 105:	learn: 0.0019130	total: 4.36s	remaining: 3.87s
# 106:	learn: 0.0019072	total: 4.4s	remaining: 3.82s
# 107:	learn: 0.0018995	total: 4.45s	remaining: 3.79s
# 108:	learn: 0.0018928	total: 4.49s	remaining: 3.75s
# 109:	learn: 0.0018874	total: 4.53s	remaining: 3.7s
# 110:	learn: 0.0018818	total: 4.56s	remaining: 3.66s
# 111:	learn: 0.0018729	total: 4.6s	remaining: 3.62s
# 112:	learn: 0.0018687	total: 4.64s	remaining: 3.57s
# 113:	learn: 0.0018613	total: 4.69s	remaining: 3.54s
# 114:	learn: 0.0018541	total: 4.72s	remaining: 3.49s
# 115:	learn: 0.0018480	total: 4.76s	remaining: 3.45s
# 116:	learn: 0.0018448	total: 4.8s	remaining: 3.4s
# 117:	learn: 0.0018411	total: 4.84s	remaining: 3.36s
# 118:	learn: 0.0018350	total: 4.88s	remaining: 3.32s
# 119:	learn: 0.0018331	total: 4.92s	remaining: 3.28s
# 120:	learn: 0.0018285	total: 4.96s	remaining: 3.24s
# 121:	learn: 0.0018239	total: 5s	remaining: 3.2s
# 122:	learn: 0.0018188	total: 5.04s	remaining: 3.15s
# 123:	learn: 0.0018126	total: 5.08s	remaining: 3.11s
# 124:	learn: 0.0018096	total: 5.12s	remaining: 3.07s
# 125:	learn: 0.0018050	total: 5.17s	remaining: 3.03s
# 126:	learn: 0.0018027	total: 5.24s	remaining: 3.01s
# 127:	learn: 0.0017976	total: 5.31s	remaining: 2.99s
# 128:	learn: 0.0017944	total: 5.37s	remaining: 2.96s
# 129:	learn: 0.0017916	total: 5.43s	remaining: 2.93s
# 130:	learn: 0.0017883	total: 5.51s	remaining: 2.9s
# 131:	learn: 0.0017859	total: 5.61s	remaining: 2.89s
# 132:	learn: 0.0017791	total: 5.67s	remaining: 2.86s
# 133:	learn: 0.0017747	total: 5.77s	remaining: 2.84s
# 134:	learn: 0.0017717	total: 5.88s	remaining: 2.83s
# 135:	learn: 0.0017676	total: 5.97s	remaining: 2.81s
# 136:	learn: 0.0017640	total: 6.08s	remaining: 2.79s
# 137:	learn: 0.0017572	total: 6.17s	remaining: 2.77s
# ...
# 91:	learn: 0.0020917	total: 5.09s	remaining: 5.97s
# 92:	learn: 0.0020856	total: 5.14s	remaining: 5.92s
# 93:	learn: 0.0020766	total: 5.17s	remaining: 5.83s
# 94:	learn: 0.0020687	total: 5.2s	remaining: 5.75s
# 95:	learn: 0.0020633	total: 5.23s	remaining: 5.67s
# 96:	learn: 0.0020575	total: 5.26s	remaining: 5.59s
# 97:	learn: 0.0020499	total: 5.29s	remaining: 5.51s
# 98:	learn: 0.0020405	total: 5.32s	remaining: 5.43s
# 99:	learn: 0.0020342	total: 5.37s	remaining: 5.37s
# 100:	learn: 0.0020229	total: 5.4s	remaining: 5.29s
# 101:	learn: 0.0020132	total: 5.43s	remaining: 5.21s
# 102:	learn: 0.0020074	total: 5.46s	remaining: 5.14s
# 103:	learn: 0.0020005	total: 5.49s	remaining: 5.07s
# 104:	learn: 0.0019954	total: 5.52s	remaining: 5s
# 105:	learn: 0.0019922	total: 5.56s	remaining: 4.93s
# 106:	learn: 0.0019842	total: 5.6s	remaining: 4.87s
# 107:	learn: 0.0019809	total: 5.63s	remaining: 4.79s
# 108:	learn: 0.0019730	total: 5.66s	remaining: 4.72s
# 109:	learn: 0.0019641	total: 5.69s	remaining: 4.65s
# 110:	learn: 0.0019567	total: 5.71s	remaining: 4.58s
# 111:	learn: 0.0019498	total: 5.75s	remaining: 4.51s
# 112:	learn: 0.0019454	total: 5.78s	remaining: 4.45s
# 113:	learn: 0.0019386	total: 5.82s	remaining: 4.39s
# 114:	learn: 0.0019315	total: 5.85s	remaining: 4.32s
# 115:	learn: 0.0019279	total: 5.88s	remaining: 4.26s
# 116:	learn: 0.0019252	total: 5.91s	remaining: 4.19s
# 117:	learn: 0.0019204	total: 5.94s	remaining: 4.13s
# 118:	learn: 0.0019149	total: 5.97s	remaining: 4.06s
# 119:	learn: 0.0019083	total: 6s	remaining: 4s
# 120:	learn: 0.0019059	total: 6.04s	remaining: 3.94s
# 121:	learn: 0.0018974	total: 6.07s	remaining: 3.88s
# 122:	learn: 0.0018890	total: 6.1s	remaining: 3.82s
# 123:	learn: 0.0018804	total: 6.14s	remaining: 3.76s
# 124:	learn: 0.0018763	total: 6.17s	remaining: 3.7s
# 125:	learn: 0.0018743	total: 6.2s	remaining: 3.64s
# 126:	learn: 0.0018720	total: 6.23s	remaining: 3.58s
# 127:	learn: 0.0018704	total: 6.27s	remaining: 3.53s
# 128:	learn: 0.0018630	total: 6.3s	remaining: 3.47s
# 129:	learn: 0.0018612	total: 6.33s	remaining: 3.41s
# 130:	learn: 0.0018569	total: 6.37s	remaining: 3.35s
# 131:	learn: 0.0018487	total: 6.4s	remaining: 3.3s
# 132:	learn: 0.0018442	total: 6.43s	remaining: 3.24s
# 133:	learn: 0.0018386	total: 6.46s	remaining: 3.18s
# 134:	learn: 0.0018298	total: 6.51s	remaining: 3.13s
# 135:	learn: 0.0018273	total: 6.54s	remaining: 3.08s
# 136:	learn: 0.0018231	total: 6.57s	remaining: 3.02s
# 137:	learn: 0.0018162	total: 6.6s	remaining: 2.96s
# 138:	learn: 0.0018116	total: 6.63s	remaining: 2.91s
# 139:	learn: 0.0018045	total: 6.66s	remaining: 2.85s
# 140:	learn: 0.0018000	total: 6.69s	remaining: 2.8s
# 141:	learn: 0.0017969	total: 6.73s	remaining: 2.75s
# 142:	learn: 0.0017919	total: 6.76s	remaining: 2.7s
# 143:	learn: 0.0017871	total: 6.79s	remaining: 2.64s
# 144:	learn: 0.0017837	total: 6.83s	remaining: 2.59s
# 145:	learn: 0.0017810	total: 6.86s	remaining: 2.54s
# 146:	learn: 0.0017759	total: 6.88s	remaining: 2.48s
# 147:	learn: 0.0017736	total: 6.91s	remaining: 2.43s
# 148:	learn: 0.0017679	total: 6.95s	remaining: 2.38s
# 149:	learn: 0.0017630	total: 6.98s	remaining: 2.33s
# 150:	learn: 0.0017603	total: 7.01s	remaining: 2.28s
# 151:	learn: 0.0017577	total: 7.04s	remaining: 2.23s
# 152:	learn: 0.0017540	total: 7.08s	remaining: 2.17s
# 153:	learn: 0.0017527	total: 7.11s	remaining: 2.12s
# 154:	learn: 0.0017499	total: 7.13s	remaining: 2.07s
# 155:	learn: 0.0017454	total: 7.18s	remaining: 2.02s
# 156:	learn: 0.0017402	total: 7.21s	remaining: 1.98s
# 157:	learn: 0.0017370	total: 7.24s	remaining: 1.93s
# 158:	learn: 0.0017324	total: 7.27s	remaining: 1.88s
# 159:	learn: 0.0017278	total: 7.31s	remaining: 1.83s
# 160:	learn: 0.0017252	total: 7.35s	remaining: 1.78s
# 161:	learn: 0.0017214	total: 7.38s	remaining: 1.73s
# 162:	learn: 0.0017178	total: 7.42s	remaining: 1.68s
# 163:	learn: 0.0017143	total: 7.45s	remaining: 1.64s
# 164:	learn: 0.0017083	total: 7.48s	remaining: 1.59s
# 165:	learn: 0.0017066	total: 7.51s	remaining: 1.54s
# 166:	learn: 0.0017038	total: 7.54s	remaining: 1.49s
# 167:	learn: 0.0017008	total: 7.57s	remaining: 1.44s
# 168:	learn: 0.0016977	total: 7.61s	remaining: 1.4s
# 169:	learn: 0.0016948	total: 7.64s	remaining: 1.35s
# 170:	learn: 0.0016895	total: 7.67s	remaining: 1.3s
# 171:	learn: 0.0016864	total: 7.7s	remaining: 1.25s
# 172:	learn: 0.0016820	total: 7.73s	remaining: 1.21s
# 173:	learn: 0.0016796	total: 7.76s	remaining: 1.16s
# 174:	learn: 0.0016765	total: 7.79s	remaining: 1.11s
# 175:	learn: 0.0016740	total: 7.83s	remaining: 1.07s
# 176:	learn: 0.0016715	total: 7.86s	remaining: 1.02s
# 177:	learn: 0.0016691	total: 7.89s	remaining: 975ms
# 178:	learn: 0.0016663	total: 7.92s	remaining: 929ms
# 179:	learn: 0.0016610	total: 7.95s	remaining: 883ms
# 180:	learn: 0.0016573	total: 7.98s	remaining: 838ms
# 181:	learn: 0.0016547	total: 8.02s	remaining: 793ms
# 182:	learn: 0.0016511	total: 8.06s	remaining: 749ms
# 183:	learn: 0.0016474	total: 8.09s	remaining: 703ms
# 184:	learn: 0.0016435	total: 8.12s	remaining: 658ms
# 185:	learn: 0.0016403	total: 8.15s	remaining: 613ms
# 186:	learn: 0.0016372	total: 8.18s	remaining: 569ms
# 187:	learn: 0.0016347	total: 8.21s	remaining: 524ms
# 188:	learn: 0.0016303	total: 8.24s	remaining: 480ms
# 189:	learn: 0.0016271	total: 8.28s	remaining: 436ms
# 190:	learn: 0.0016248	total: 8.31s	remaining: 392ms
# 191:	learn: 0.0016225	total: 8.34s	remaining: 348ms
# 192:	learn: 0.0016208	total: 8.38s	remaining: 304ms
# 193:	learn: 0.0016175	total: 8.41s	remaining: 260ms
# 194:	learn: 0.0016137	total: 8.44s	remaining: 216ms
# 195:	learn: 0.0016117	total: 8.47s	remaining: 173ms
# 196:	learn: 0.0016093	total: 8.51s	remaining: 130ms
# 197:	learn: 0.0016078	total: 8.54s	remaining: 86.2ms
# 198:	learn: 0.0016035	total: 8.57s	remaining: 43.1ms
# 199:	learn: 0.0016016	total: 8.6s	remaining: 0us
# 0:	learn: 0.3933556	total: 37.3ms	remaining: 7.43s
# 1:	learn: 0.2069623	total: 92.9ms	remaining: 9.2s
# 2:	learn: 0.1102914	total: 172ms	remaining: 11.3s
# 3:	learn: 0.0620673	total: 226ms	remaining: 11.1s
# 4:	learn: 0.0344489	total: 293ms	remaining: 11.4s
# 5:	learn: 0.0212019	total: 347ms	remaining: 11.2s
# 6:	learn: 0.0141092	total: 398ms	remaining: 11s
# 7:	learn: 0.0104332	total: 455ms	remaining: 10.9s
# 8:	learn: 0.0081723	total: 512ms	remaining: 10.9s
# 9:	learn: 0.0067328	total: 570ms	remaining: 10.8s
# 10:	learn: 0.0059225	total: 618ms	remaining: 10.6s
# 11:	learn: 0.0052998	total: 666ms	remaining: 10.4s
# 12:	learn: 0.0047386	total: 722ms	remaining: 10.4s
# 13:	learn: 0.0044829	total: 773ms	remaining: 10.3s
# 14:	learn: 0.0042343	total: 820ms	remaining: 10.1s
# 15:	learn: 0.0039813	total: 866ms	remaining: 9.96s
# 16:	learn: 0.0038760	total: 913ms	remaining: 9.82s
# 17:	learn: 0.0038085	total: 976ms	remaining: 9.86s
# 18:	learn: 0.0037450	total: 1.02s	remaining: 9.74s
# 19:	learn: 0.0036682	total: 1.07s	remaining: 9.62s
# 20:	learn: 0.0036311	total: 1.12s	remaining: 9.52s
# 21:	learn: 0.0035656	total: 1.16s	remaining: 9.41s
# 22:	learn: 0.0034893	total: 1.22s	remaining: 9.36s
# 23:	learn: 0.0034135	total: 1.26s	remaining: 9.27s
# 24:	learn: 0.0033222	total: 1.32s	remaining: 9.24s
# 25:	learn: 0.0032483	total: 1.37s	remaining: 9.14s
# 26:	learn: 0.0032087	total: 1.41s	remaining: 9.06s
# 27:	learn: 0.0031531	total: 1.46s	remaining: 8.97s
# 28:	learn: 0.0031113	total: 1.52s	remaining: 8.94s
# 29:	learn: 0.0030480	total: 1.56s	remaining: 8.86s
# 30:	learn: 0.0030084	total: 1.61s	remaining: 8.78s
# 31:	learn: 0.0029794	total: 1.66s	remaining: 8.72s
# 32:	learn: 0.0029343	total: 1.71s	remaining: 8.64s
# 33:	learn: 0.0029073	total: 1.75s	remaining: 8.56s
# 34:	learn: 0.0028798	total: 1.8s	remaining: 8.49s
# 35:	learn: 0.0028495	total: 1.85s	remaining: 8.45s
# 36:	learn: 0.0028281	total: 1.91s	remaining: 8.43s
# 37:	learn: 0.0027907	total: 1.96s	remaining: 8.35s
# 38:	learn: 0.0027641	total: 2s	remaining: 8.28s
# 39:	learn: 0.0027464	total: 2.05s	remaining: 8.2s
# 40:	learn: 0.0027127	total: 2.1s	remaining: 8.13s
# 41:	learn: 0.0026947	total: 2.15s	remaining: 8.08s
# 42:	learn: 0.0026774	total: 2.2s	remaining: 8.03s
# 43:	learn: 0.0026534	total: 2.24s	remaining: 7.96s
# 44:	learn: 0.0026394	total: 2.3s	remaining: 7.91s
# 45:	learn: 0.0026104	total: 2.34s	remaining: 7.85s
# 46:	learn: 0.0025901	total: 2.4s	remaining: 7.82s
# 47:	learn: 0.0025501	total: 2.46s	remaining: 7.78s
# 48:	learn: 0.0025234	total: 2.5s	remaining: 7.71s
# 49:	learn: 0.0025133	total: 2.56s	remaining: 7.68s
# 50:	learn: 0.0024841	total: 2.61s	remaining: 7.63s
# 51:	learn: 0.0024598	total: 2.66s	remaining: 7.57s
# 52:	learn: 0.0024439	total: 2.71s	remaining: 7.5s
# 53:	learn: 0.0024296	total: 2.75s	remaining: 7.44s
# 54:	learn: 0.0024103	total: 2.8s	remaining: 7.38s
# 55:	learn: 0.0024012	total: 2.85s	remaining: 7.34s
# 56:	learn: 0.0023884	total: 2.9s	remaining: 7.28s
# 57:	learn: 0.0023762	total: 2.94s	remaining: 7.21s
# 58:	learn: 0.0023617	total: 2.99s	remaining: 7.15s
# 59:	learn: 0.0023423	total: 3.04s	remaining: 7.09s
# 60:	learn: 0.0023279	total: 3.09s	remaining: 7.05s
# 61:	learn: 0.0023174	total: 3.14s	remaining: 6.99s
# 62:	learn: 0.0023027	total: 3.19s	remaining: 6.93s
# 63:	learn: 0.0022750	total: 3.23s	remaining: 6.88s
# 64:	learn: 0.0022547	total: 3.29s	remaining: 6.82s
# 65:	learn: 0.0022451	total: 3.35s	remaining: 6.79s
# 66:	learn: 0.0022364	total: 3.4s	remaining: 6.74s
# 67:	learn: 0.0022162	total: 3.44s	remaining: 6.68s
# 68:	learn: 0.0022064	total: 3.49s	remaining: 6.62s
# 69:	learn: 0.0021969	total: 3.54s	remaining: 6.58s
# 70:	learn: 0.0021878	total: 3.6s	remaining: 6.54s
# 71:	learn: 0.0021743	total: 3.64s	remaining: 6.48s
# 72:	learn: 0.0021578	total: 3.69s	remaining: 6.42s
# 73:	learn: 0.0021475	total: 3.74s	remaining: 6.37s
# 74:	learn: 0.0021345	total: 3.79s	remaining: 6.31s
# 75:	learn: 0.0021284	total: 3.84s	remaining: 6.27s
# 76:	learn: 0.0021182	total: 3.89s	remaining: 6.21s
# 77:	learn: 0.0021110	total: 3.94s	remaining: 6.16s
# 78:	learn: 0.0020972	total: 3.98s	remaining: 6.1s
# 79:	learn: 0.0020884	total: 4.03s	remaining: 6.05s
# 80:	learn: 0.0020768	total: 4.09s	remaining: 6.01s
# 81:	learn: 0.0020697	total: 4.15s	remaining: 5.97s
# 82:	learn: 0.0020614	total: 4.2s	remaining: 5.92s
# 83:	learn: 0.0020558	total: 4.25s	remaining: 5.87s
# 84:	learn: 0.0020527	total: 4.31s	remaining: 5.83s
# 85:	learn: 0.0020449	total: 4.36s	remaining: 5.78s
# 86:	learn: 0.0020362	total: 4.41s	remaining: 5.72s
# 87:	learn: 0.0020244	total: 4.45s	remaining: 5.67s
# 88:	learn: 0.0020199	total: 4.5s	remaining: 5.61s
# 89:	learn: 0.0020142	total: 4.56s	remaining: 5.58s
# 90:	learn: 0.0020075	total: 4.61s	remaining: 5.52s
# 91:	learn: 0.0019993	total: 4.66s	remaining: 5.47s
# 92:	learn: 0.0019930	total: 4.71s	remaining: 5.41s
# 93:	learn: 0.0019857	total: 4.77s	remaining: 5.38s
# 94:	learn: 0.0019803	total: 4.82s	remaining: 5.33s
# 95:	learn: 0.0019732	total: 4.87s	remaining: 5.27s
# 96:	learn: 0.0019677	total: 4.91s	remaining: 5.22s
# 97:	learn: 0.0019619	total: 4.96s	remaining: 5.17s
# 98:	learn: 0.0019557	total: 5.02s	remaining: 5.12s
# 99:	learn: 0.0019509	total: 5.07s	remaining: 5.07s
# 100:	learn: 0.0019460	total: 5.12s	remaining: 5.02s
# 101:	learn: 0.0019418	total: 5.17s	remaining: 4.96s
# 102:	learn: 0.0019361	total: 5.21s	remaining: 4.91s
# 103:	learn: 0.0019310	total: 5.27s	remaining: 4.86s
# 104:	learn: 0.0019243	total: 5.32s	remaining: 4.81s
# 105:	learn: 0.0019199	total: 5.37s	remaining: 4.76s
# 106:	learn: 0.0019126	total: 5.43s	remaining: 4.72s
# 107:	learn: 0.0019060	total: 5.49s	remaining: 4.67s
# 108:	learn: 0.0019015	total: 5.54s	remaining: 4.63s
# 109:	learn: 0.0018957	total: 5.6s	remaining: 4.58s
# 110:	learn: 0.0018911	total: 5.65s	remaining: 4.53s
# 111:	learn: 0.0018867	total: 5.71s	remaining: 4.48s
# 112:	learn: 0.0018824	total: 5.75s	remaining: 4.43s
# 113:	learn: 0.0018791	total: 5.8s	remaining: 4.38s
# 114:	learn: 0.0018726	total: 5.85s	remaining: 4.33s
# 115:	learn: 0.0018663	total: 5.9s	remaining: 4.27s
# 116:	learn: 0.0018606	total: 5.95s	remaining: 4.22s
# 117:	learn: 0.0018562	total: 6s	remaining: 4.17s
# 118:	learn: 0.0018530	total: 6.05s	remaining: 4.12s
# 119:	learn: 0.0018446	total: 6.09s	remaining: 4.06s
# 120:	learn: 0.0018417	total: 6.14s	remaining: 4.01s
# 121:	learn: 0.0018362	total: 6.2s	remaining: 3.96s
# 122:	learn: 0.0018341	total: 6.25s	remaining: 3.91s
# 123:	learn: 0.0018282	total: 6.3s	remaining: 3.86s
# 124:	learn: 0.0018215	total: 6.35s	remaining: 3.81s
# 125:	learn: 0.0018165	total: 6.39s	remaining: 3.75s
# 126:	learn: 0.0018115	total: 6.45s	remaining: 3.71s
# 127:	learn: 0.0018092	total: 6.5s	remaining: 3.65s
# 128:	learn: 0.0018073	total: 6.55s	remaining: 3.61s
# 129:	learn: 0.0018022	total: 6.6s	remaining: 3.55s
# 130:	learn: 0.0017972	total: 6.65s	remaining: 3.5s
# 131:	learn: 0.0017903	total: 6.7s	remaining: 3.45s
# 132:	learn: 0.0017838	total: 6.75s	remaining: 3.4s
# 133:	learn: 0.0017809	total: 6.8s	remaining: 3.35s
# 134:	learn: 0.0017772	total: 6.84s	remaining: 3.29s
# 135:	learn: 0.0017723	total: 6.89s	remaining: 3.24s
# 136:	learn: 0.0017709	total: 6.95s	remaining: 3.19s
# 137:	learn: 0.0017669	total: 7s	remaining: 3.14s
# 138:	learn: 0.0017618	total: 7.05s	remaining: 3.09s
# 139:	learn: 0.0017587	total: 7.1s	remaining: 3.04s
# 140:	learn: 0.0017558	total: 7.14s	remaining: 2.99s
# 141:	learn: 0.0017524	total: 7.2s	remaining: 2.94s
# 142:	learn: 0.0017482	total: 7.25s	remaining: 2.89s
# 143:	learn: 0.0017436	total: 7.3s	remaining: 2.84s
# 144:	learn: 0.0017404	total: 7.37s	remaining: 2.8s
# 145:	learn: 0.0017354	total: 7.44s	remaining: 2.75s
# 146:	learn: 0.0017325	total: 7.54s	remaining: 2.72s
# 147:	learn: 0.0017287	total: 7.64s	remaining: 2.69s
# 148:	learn: 0.0017248	total: 7.75s	remaining: 2.65s
# 149:	learn: 0.0017211	total: 7.87s	remaining: 2.62s
# 150:	learn: 0.0017193	total: 8s	remaining: 2.6s
# 151:	learn: 0.0017158	total: 8.14s	remaining: 2.57s
# 152:	learn: 0.0017120	total: 8.27s	remaining: 2.54s
# 153:	learn: 0.0017080	total: 8.4s	remaining: 2.51s
# 154:	learn: 0.0017035	total: 8.52s	remaining: 2.47s
# 155:	learn: 0.0017005	total: 8.67s	remaining: 2.44s
# 156:	learn: 0.0016960	total: 8.8s	remaining: 2.41s
# 157:	learn: 0.0016941	total: 8.93s	remaining: 2.37s
# 158:	learn: 0.0016898	total: 9.06s	remaining: 2.34s
# 159:	learn: 0.0016879	total: 9.19s	remaining: 2.3s
# 160:	learn: 0.0016854	total: 9.32s	remaining: 2.26s
# 161:	learn: 0.0016829	total: 9.46s	remaining: 2.22s
# 162:	learn: 0.0016792	total: 9.59s	remaining: 2.18s
# 163:	learn: 0.0016760	total: 9.74s	remaining: 2.14s
# 164:	learn: 0.0016704	total: 9.87s	remaining: 2.09s
# 165:	learn: 0.0016683	total: 10s	remaining: 2.05s
# 166:	learn: 0.0016654	total: 10.1s	remaining: 2s
# 167:	learn: 0.0016609	total: 10.3s	remaining: 1.96s
# 168:	learn: 0.0016572	total: 10.4s	remaining: 1.91s
# 169:	learn: 0.0016552	total: 10.5s	remaining: 1.85s
# 170:	learn: 0.0016516	total: 10.5s	remaining: 1.78s
# 171:	learn: 0.0016498	total: 10.6s	remaining: 1.72s
# 172:	learn: 0.0016469	total: 10.6s	remaining: 1.66s
# 173:	learn: 0.0016440	total: 10.7s	remaining: 1.6s
# 174:	learn: 0.0016387	total: 10.7s	remaining: 1.53s
# 175:	learn: 0.0016358	total: 10.8s	remaining: 1.47s
# 176:	learn: 0.0016328	total: 10.8s	remaining: 1.41s
# 177:	learn: 0.0016290	total: 10.9s	remaining: 1.35s
# 178:	learn: 0.0016258	total: 10.9s	remaining: 1.28s
# 179:	learn: 0.0016202	total: 11s	remaining: 1.22s
# 180:	learn: 0.0016178	total: 11s	remaining: 1.16s
# 181:	learn: 0.0016138	total: 11.1s	remaining: 1.1s
# 182:	learn: 0.0016112	total: 11.1s	remaining: 1.03s
# 183:	learn: 0.0016076	total: 11.2s	remaining: 974ms
# 184:	learn: 0.0016045	total: 11.2s	remaining: 912ms
# 185:	learn: 0.0016007	total: 11.3s	remaining: 850ms
# 186:	learn: 0.0015982	total: 11.3s	remaining: 789ms
# 187:	learn: 0.0015960	total: 11.4s	remaining: 728ms
# 188:	learn: 0.0015937	total: 11.5s	remaining: 667ms
# 189:	learn: 0.0015912	total: 11.5s	remaining: 605ms
# 190:	learn: 0.0015885	total: 11.6s	remaining: 544ms
# 191:	learn: 0.0015861	total: 11.6s	remaining: 483ms
# 192:	learn: 0.0015838	total: 11.7s	remaining: 423ms
# 193:	learn: 0.0015819	total: 11.7s	remaining: 362ms
# 194:	learn: 0.0015772	total: 11.8s	remaining: 302ms
# 195:	learn: 0.0015748	total: 11.8s	remaining: 241ms
# 196:	learn: 0.0015725	total: 11.9s	remaining: 181ms
# 197:	learn: 0.0015706	total: 11.9s	remaining: 120ms
# 198:	learn: 0.0015667	total: 12s	remaining: 60.1ms
# 199:	learn: 0.0015652	total: 12s	remaining: 0us
# Best Parameters: OrderedDict([('max_depth', 10)])
# Best Score: 0.9993459006562532
# ['bayes_search_cat.sav']

# %%
# specify the path
path = '/content/drive/MyDrive/Colab Notebooks/Final Project/bayes_search_cat.sav'
# load the model
loaded_model_cat = load(path)

# Make predictions on the test data
y_pred = loaded_model_cat.predict(X_test)
y_scores = loaded_model_cat.predict_proba(X_test)[:, 1]

# Accuracy
accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
print(f"Accuracy for class 0: {accuracy_class_0*100}%")
print(f"Accuracy for class 1: {accuracy_class_1*100}%")

# F2 score
f2 = fbeta_score(y_test, y_pred, beta=2)
print(f"F2 Score: {f2}")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title("Confusion Matrix")
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_scores)  # Calculate precision, recall
pr_auc = auc(recall, precision)  # Calculate Precision-Recall AUC
plt.figure()
plt.plot(recall, precision, label=f"Precision-Recall Curve (AUC = {pr_auc:.2f})")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()

# Classification report
report = classification_report(y_test, y_pred)
print(f"Classification Report:\n{report}")
# Out:
# Accuracy for class 0: 99.98961391210504%
# Accuracy for class 1: 80.27597402597402%
# F2 Score: 0.8296283868802953
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    837659
#            1       0.96      0.80      0.87      2464
#
#     accuracy                           1.00    840123
#    macro avg       0.98      0.90      0.94    840123
# weighted avg       1.00      1.00      1.00    840123
